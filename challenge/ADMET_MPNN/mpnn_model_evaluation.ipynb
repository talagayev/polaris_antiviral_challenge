# %%
import pandas as pd

# %%
test_pred = pd.read_csv('/mdspace/polaris_ml_challenge/chemprop_model_sijie/results/admet_chemprop_results/test_performance.csv')
test_pred
# Out:
#                                    preprocessedSmiles  \
# 0   O=C(NCC(F)F)C(Nc1cc2c(cc1Br)CNC2)c1cc(Cl)cc(C2...
# 1           Cc1c(C(=O)Nc2cc(C3CCOC3)ccn2)cc(C2CC2)n1C
# 2           Cc1ccc2oc(Sc3cc(-c4ccccc4)nc4ncnn34)nc2c1
# 3            CCC1CC(C(F)(F)F)CCN1C(=O)Cc1cncc2ccccc12
# 4   CC1CN(c2cncc3ccccc23)C(=O)C12CN(Cc1cc(=O)[nH]c...
# ..                                                ...
# 66  CN(C)C(=O)c1cc(CCCn2ccc3cc(-c4noc(C(F)(F)F)n4)...
# 67                Cc1nnc(Sc2cc(-c3ccccc3)nc3ncnn23)o1
# 68       Cn1c(Sc2cc(-c3ccccc3)nc3ncnn23)nnc1-c1ccncc1
# 69          NCc1cccc(NC(=O)c2cccn3cc(CN4CCCC4)nc23)c1
# 70  CNC(=O)C(Nc1cc(CN)cc(-c2nn[nH]n2)c1)c1cc(Cl)cc...
#
#     in-vitro_HLM_bienta: CLint (Num) (uL/min/mg)  \
# 0                                     -10.156063
# 1                                     143.177649
# 2                                      61.702099
# 3                                     183.902229
# 4                                     117.854650
# ...

# %%
# read y_true
y_true = pd.read_csv('/mdspace/polaris_ml_challenge/chemprop_model_sijie/train_test_split/test_admet.csv')
y_true
# Out:
#                                    preprocessedSmiles  \
# 0   O=C(NCC(F)F)C(Nc1cc2c(cc1Br)CNC2)c1cc(Cl)cc(C2...
# 1           Cc1c(C(=O)Nc2cc(C3CCOC3)ccn2)cc(C2CC2)n1C
# 2           Cc1ccc2oc(Sc3cc(-c4ccccc4)nc4ncnn34)nc2c1
# 3            CCC1CC(C(F)(F)F)CCN1C(=O)Cc1cncc2ccccc12
# 4   CC1CN(c2cncc3ccccc23)C(=O)C12CN(Cc1cc(=O)[nH]c...
# ..                                                ...
# 66  CN(C)C(=O)c1cc(CCCn2ccc3cc(-c4noc(C(F)(F)F)n4)...
# 67                Cc1nnc(Sc2cc(-c3ccccc3)nc3ncnn23)o1
# 68       Cn1c(Sc2cc(-c3ccccc3)nc3ncnn23)nnc1-c1ccncc1
# 69          NCc1cccc(NC(=O)c2cccn3cc(CN4CCCC4)nc23)c1
# 70  CNC(=O)C(Nc1cc(CN)cc(-c2nn[nH]n2)c1)c1cc(Cl)cc...
#
#     in-vitro_HLM_bienta: CLint (Num) (uL/min/mg)  \
# 0                                            NaN
# 1                                           57.7
# 2                                            NaN
# 3                                            NaN
# 4                                            2.0
# ...

# %%
# caluculate the performance, including RMSE, MAE, R2, drop the value of 'in-vitro_HLM_bienta: CLint (Num) (uL/min/mg)'  in y_true is NaN
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
# write a loop to run the same analysis for all targets
targets_list = ['in-vitro_HLM_bienta: CLint (Num) (uL/min/mg)', 'in-vitro_KSOL-PBS_bienta: mean_solubility (Num) (uM)',	'in-vitro_LogD_bienta: LogD (Num)',	'in-vitro_MDR1-MDCKII-Papp_bienta: mean_Papp_A_to_B (Num) (10^-6 cm/s)',	'in-vitro_MLM_bienta: CLint (Num) (uL/min/mg)']
for target in targets_list:
    y_true_tmp = y_true[target].dropna()
    test_pred_tmp = test_pred[target].loc[y_true_tmp.index]
    RMSE = np.sqrt(mean_squared_error(y_true_tmp, test_pred_tmp))
    MAE = mean_absolute_error(y_true_tmp, test_pred_tmp)
    R2 = r2_score(y_true_tmp, test_pred_tmp)
    print('RMSE:', RMSE, 'MAE:', MAE, 'R2:', R2)
    plt.scatter(y_true_tmp, test_pred_tmp)
    plt.xlabel('True Value')
    plt.ylabel('Predicted Value')
    plt.title(f'True vs Predicted Value for {target}')
    plt.show()
# Out:
# RMSE: 139.98787424903605 MAE: 77.74108931180028 R2: 0.06550735466981183
# RMSE: 93.55289201179636 MAE: 72.67965933500162 R2: 0.6665236046693035
# RMSE: 0.7733432697308331 MAE: 0.5733494445081722 R2: 0.664646309869072
# RMSE: 4.013501699193639 MAE: 2.835514974399885 R2: 0.5459009893948228
# RMSE: 219.0166556540479 MAE: 146.11980640850544 R2: 0.15261644907238836
