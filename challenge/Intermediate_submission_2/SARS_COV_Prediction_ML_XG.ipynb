# %% [markdown]
# # Ligand ADMET and Potency (Property Prediction)
#
# The [ADMET](https://polarishub.io/competitions/asap-discovery/antiviral-admet-2025) and [Potency](https://polarishub.io/competitions/asap-discovery/antiviral-potency-2025) Challenge of the [ASAP Discovery competition](https://polarishub.io/blog/antiviral-competition) take the shape of a property prediction task. Given the SMILES (or, to be more precise, the CXSMILES) of a molecule, you are asked to predict the numerical properties of said molecule. This is a relatively straight-forward application of ML and this notebook will quickly get you up and running!
#
# To begin with, choose one of the two challenges! The code will look the same for both.

# %%
import polaris as po
from polaris.hub.client import PolarisHubClient
import csv

# %%
client = PolarisHubClient()
client.login()
# Out:
# [2025-02-25 23:12:27] INFO     You are successfully logged in to the Polaris Hub.                     ]8;id=623199;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/hub/client.py\client.py]8;;\:]8;id=394731;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/hub/client.py#252\252]8;;\

# %%
CHALLENGE = "antiviral-potency-2025"  # or: "antiviral-potency-2025"

# %% [markdown]
# ## Load the competition
#
# Let's first load the competition from Polaris.
#
# Make sure you are logged in! If not, simply run `polaris login` and follow the instructions.

# %%
import polaris as po

competition = po.load_competition(f"asap-discovery/{CHALLENGE}")
# Out:
# [2025-02-25 23:12:30] INFO     The version of Polaris that was used to create the artifact (0.11.0) ]8;id=842270;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/_artifact.py\_artifact.py]8;;\:]8;id=380586;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/_artifact.py#92\92]8;;\
#                                is different from the currently installed version of Polaris
#                                (0.11.5).
#                       WARNING  You're loading data from a remote location. If the dataset is small     ]8;id=660479;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=285079;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py#182\182]8;;\
#                                enough, consider caching the dataset first using
#                                CompetitionSpecification.cache() for more performant data access.

# %% [markdown]
# As suggested in the logs, we'll cache the dataset. Note that this is not strictly necessary, but it does speed up later steps.

# %%
competition.cache()
# Out:
# Output()
# [23:12:32] Copying to destination                                                                      ]8;id=553231;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=490743;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py#381\381]8;;\
#            /home/valerij/.cache/polaris/datasets/3395bbb1-34d7-42ac-b7bd-a608427a2891/data.zarr
#            For large Zarr archives, this may take a while.                                             ]8;id=204138;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=683824;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/dataset/_base.py#382\382]8;;\
# [23:12:33]  Success: Copying Zarr keys                                                                ]8;id=319035;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=276128;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/utils/context.py#53\53]8;;\
#             Success: Copying Zarr archive                                                             ]8;id=143272;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=728351;file:///home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/polaris/utils/context.py#53\53]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# '/home/valerij/.cache/polaris/datasets/3395bbb1-34d7-42ac-b7bd-a608427a2891'

# %% [markdown]
# Let's get the train and test set and take a look at the data structure.

# %%
train, test = competition.get_train_test_split()

# %%
train[10]
# Out:
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)C12CN(S(C)(=O)=O)C2',
#  {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.69})

# %%
print(type(train))
# Out:
# <class 'polaris.dataset._subset.Subset'>

# %%
train[:1]
# Out:
# (array(['COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C |&1:3|'],
#        dtype=object),
#  {'pIC50 (SARS-CoV-2 Mpro)': array([nan]),
#   'pIC50 (MERS-CoV Mpro)': array([4.19])})

# %%
import pandas as pd

smiles_list_test = []

# Iterate through train and populate the lists
for t in test:
    smiles_list_test.append(t)

# Create the DataFrame
potency_df_test = pd.DataFrame({
    'SMILES': smiles_list_test,
})

# %%
potency_df_test
# Out:
#                                                 SMILES
# 0    C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...
# 1    CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# 2    CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...
# 3    CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# 4    CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# ..                                                 ...
# 292  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# 293  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# 294  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...
# 295  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
# 296  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
#
# [297 rows x 1 columns]

# %%
import pandas as pd
# Initialize lists to hold data for DataFrame
smiles_list = []
sars_list = []
mers_list = []

# Iterate through train and populate the lists
for t in train:
    smiles_list.append(t[0])
    sars_list.append(t[1].get('pIC50 (SARS-CoV-2 Mpro)', None))
    mers_list.append(t[1].get('pIC50 (MERS-CoV Mpro)', None))

# Create the DataFrame
potency_df_sars = pd.DataFrame({
    'SMILES': smiles_list,
    'pIC50 (SARS-CoV-2 Mpro)': sars_list,
})

# Create the DataFrame
potency_df_mers = pd.DataFrame({
    'SMILES': smiles_list,
    'pIC50 (MERS-CoV Mpro)': mers_list,
})

# Display the DataFrame
print(potency_df_sars)
print(potency_df_mers)
# Out:
#                                                  SMILES  \
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# ...                                                 ...
# 1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...
# 1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...
# 1028  CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
# 1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...
# 1030  O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
#
#       pIC50 (SARS-CoV-2 Mpro)
# 0                         NaN
# 1                        5.29
# 2                         NaN
# 3                        6.11
# 4                        5.62
# ...                       ...
# 1026                     6.38
# 1027                     6.09
# 1028                      NaN
# 1029                     5.06
# 1030                      NaN
#
# [1031 rows x 2 columns]
#                                                  SMILES  pIC50 (MERS-CoV Mpro)
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...                   4.19
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...                   4.92
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...                   4.73
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...                   4.90
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...                   4.81
# ...                                                 ...                    ...
# 1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...                   5.57
# 1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...                   4.60
# 1028  CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...                   4.22
# 1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...                   4.40
# 1030  O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...                   4.22
#
# [1031 rows x 2 columns]

# %%
print(len(train))
# Out:
# 1031

# %%
print(len(test))
# Out:
# 297

# %% [markdown]
# ### Raw data dump
# We've decided to sacrifice the completeness of the scientific data to improve its ease of use. For those that are interested, you can also access the raw data dump that this dataset has been created from.

# %% [markdown]
# ## Build a model
# Next, we'll train a simple baseline model using scikit-learn.
#
# You'll notice that the challenge has multiple targets.

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

# %%
mers_props = [
    {"name": "pIC50 (MERS-CoV Mpro)", "task": "REGRESSION"},]

# %%
sars_props = [
    {"name": "pIC50 (SARS-CoV-2 Mpro)", "task": "REGRESSION"},]

# %% [markdown]
# ## SARS

# %%
potency_df_sars
# Out:
#                                                  SMILES  \
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# ...                                                 ...
# 1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...
# 1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...
# 1028  CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
# 1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...
# 1030  O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
#
#       pIC50 (SARS-CoV-2 Mpro)
# 0                         NaN
# 1                        5.29
# 2                         NaN
# 3                        6.11
# 4                        5.62
# ...                       ...
# 1026                     6.38
# 1027                     6.09
# 1028                      NaN
# 1029                     5.06
# 1030                      NaN
#
# [1031 rows x 2 columns]

# %%
dataset_sars = QSPRDataset(
    name="MultiTaskTutorialDataset",
    df=potency_df_sars,
    target_props=sars_props,
    store_dir="sars_output_adjusted/data",
    random_state=42,
)

dataset_sars.getDF()
# Out:
# qsprpred - WARNING - Existing data set found, but also found a data frame in store. Refusing to overwrite data. If you want to overwrite data in store, set overwrite=True.
#                                                                          SMILES  \
# QSPRID
# MultiTaskTutorialDataset_000  C=C(CN1CCc2ccc(Cl)cc2C1C(=O)Nc1cncc2ccccc12)C(...
# MultiTaskTutorialDataset_001  C=C(CN1CCc2ccc(Cl)cc2C1C(=O)Nc1cncc2ccccc12)C(...
# MultiTaskTutorialDataset_002  C=C(CN1CCc2ccc(Cl)cc2C1C(=O)Nc1cncc2ccccc12)C(...
# MultiTaskTutorialDataset_003  C=C(CN(C(=O)C1CCOc2ccc(Cl)cc21)c1cncc2ccccc12)...
# MultiTaskTutorialDataset_004  C=C(CN(C(=O)C1CCOc2ccc(Cl)cc21)c1cncc2ccccc12)...
# ...                                                                         ...
# MultiTaskTutorialDataset_837          O=C(Cc1cncc2ccccc12)N1CCC([C@H]2CCOC2)CC1
# MultiTaskTutorialDataset_838                 O=C(Cc1cncc2ccccc12)N1CCCC2(CC2)C1
# MultiTaskTutorialDataset_839  CNS(=O)(=O)OCC(=O)N1CCN(Cc2cccc(Cl)c2)[C@H]2CS...
# MultiTaskTutorialDataset_840        O=C(Cc1cncc2ccccc12)N1CC[C@@H]2CCCC[C@H]2C1
# MultiTaskTutorialDataset_841           C[C@H]1CCCN(C(=O)Cc2cncc3ccccc23)[C@H]1C
#
#                               pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000                     5.29
# MultiTaskTutorialDataset_001                     6.11
# MultiTaskTutorialDataset_002                     5.62
# MultiTaskTutorialDataset_003                     6.45
# MultiTaskTutorialDataset_004                     5.56
# ...                                               ...
# MultiTaskTutorialDataset_837                     4.68
# MultiTaskTutorialDataset_838                     4.41
# MultiTaskTutorialDataset_839                     6.38
# MultiTaskTutorialDataset_840                     6.09
# MultiTaskTutorialDataset_841                     5.06
#
#                                                     QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_000  MultiTaskTutorialDataset_000
# MultiTaskTutorialDataset_001  MultiTaskTutorialDataset_001
# MultiTaskTutorialDataset_002  MultiTaskTutorialDataset_002
# MultiTaskTutorialDataset_003  MultiTaskTutorialDataset_003
# MultiTaskTutorialDataset_004  MultiTaskTutorialDataset_004
# ...                                                    ...
# MultiTaskTutorialDataset_837  MultiTaskTutorialDataset_837
# MultiTaskTutorialDataset_838  MultiTaskTutorialDataset_838
# MultiTaskTutorialDataset_839  MultiTaskTutorialDataset_839
# MultiTaskTutorialDataset_840  MultiTaskTutorialDataset_840
# MultiTaskTutorialDataset_841  MultiTaskTutorialDataset_841
#
#                               pIC50 (SARS-CoV-2 Mpro)_original  Split_IsTrain
# QSPRID
# MultiTaskTutorialDataset_000                              5.29           True
# MultiTaskTutorialDataset_001                              6.11           True
# MultiTaskTutorialDataset_002                              5.62           True
# MultiTaskTutorialDataset_003                              6.45           True
# MultiTaskTutorialDataset_004                              5.56           True
# ...                                                        ...            ...
# MultiTaskTutorialDataset_837                              4.68           True
# MultiTaskTutorialDataset_838                              4.41           True
# MultiTaskTutorialDataset_839                              6.38           True
# MultiTaskTutorialDataset_840                              6.09           True
# MultiTaskTutorialDataset_841                              5.06           True
#
# [842 rows x 5 columns]

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_sars)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_sars.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=8, nBits=256)],
    recalculate_features=True,
    feature_filters=[LowVarianceFilter(0.001)],
    feature_standardizer=StandardScaler()
)

print(f"Number of samples train set: {len(dataset_sars.y)}")
print(f"Number of samples test set: {len(dataset_sars.y_ind)}")

dataset_sars.save()
# Out:
# Number of samples train set: 673
# Number of samples test set: 169

# %%
from qsprpred.models import SklearnModel
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor
from qsprpred.models import CrossValAssessor, TestSetAssessor

os.makedirs("class_models/XG_models_clust", exist_ok=True)

# This is an SKlearn model, so we will initialize it with the SklearnModel class
model_sars = SklearnModel(
    base_dir="class_models/XG_models_clust_sars_adjusted",
    alg=XGBRegressor,
    name="XGMorgan_clustsplit"
)

import numpy as np
from qsprpred.models import GridSearchOptimization, CrossValAssessor

# %%
from qsprpred.models import OptunaOptimization, TestSetAssessor
from sklearn.model_selection import KFold

# Note the specification of the hyperparameter types as first item in the list
search_space = {"max_depth": ["int", 1, 20],
                "gamma": ["int", 0, 20],
                "max_delta_step": ["int", 0, 20],
                "min_child_weight": ["int", 1, 20],
                "learning_rate": ["float", 0.001, 1],
                "subsample": ["float", 0.001, 1],
                "n_estimators": ["int", 10, 250],
               }

# Optuna gridsearcher with the TestSetAssessor
gridsearcher = OptunaOptimization(
    n_trials=500,
    param_grid=search_space,
    model_assessor=TestSetAssessor(scoring='r2'),
)
gridsearcher.optimize(model_sars, dataset_sars)
# Out:
# [I 2025-02-26 01:33:03,638] A new study created in memory with name: no-name-1689f3fc-918c-4591-b9f3-0f660d1b69ab
# [I 2025-02-26 01:33:08,742] Trial 0 finished with value: 0.1426323856748366 and parameters: {'max_depth': 8, 'gamma': 19, 'max_delta_step': 15, 'min_child_weight': 12, 'learning_rate': 0.1568626218019941, 'subsample': 0.15683852581586644, 'n_estimators': 23}. Best is trial 0 with value: 0.1426323856748366.
# [I 2025-02-26 01:33:09,661] Trial 1 finished with value: 0.12314740850092776 and parameters: {'max_depth': 18, 'gamma': 12, 'max_delta_step': 14, 'min_child_weight': 1, 'learning_rate': 0.9699399423098324, 'subsample': 0.8326101981596213, 'n_estimators': 61}. Best is trial 0 with value: 0.1426323856748366.
# [I 2025-02-26 01:33:11,242] Trial 2 finished with value: 0.260143188084316 and parameters: {'max_depth': 4, 'gamma': 3, 'max_delta_step': 6, 'min_child_weight': 11, 'learning_rate': 0.43251307362347363, 'subsample': 0.2919379110578439, 'n_estimators': 157}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:12,483] Trial 3 finished with value: -0.10887531409538487 and parameters: {'max_depth': 3, 'gamma': 6, 'max_delta_step': 7, 'min_child_weight': 10, 'learning_rate': 0.7853907854316206, 'subsample': 0.2004741083762014, 'n_estimators': 133}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:16,487] Trial 4 finished with value: 0.15519466361208556 and parameters: {'max_depth': 12, 'gamma': 0, 'max_delta_step': 12, 'min_child_weight': 4, 'learning_rate': 0.06598654139229423, 'subsample': 0.9489366517160799, 'n_estimators': 242}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:18,090] Trial 5 finished with value: 0.24367035557188832 and parameters: {'max_depth': 17, 'gamma': 6, 'max_delta_step': 2, 'min_child_weight': 14, 'learning_rate': 0.4407123412458617, 'subsample': 0.12291619660993405, 'n_estimators': 129}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:18,780] Trial 6 finished with value: 0.1945310668312138 and parameters: {'max_depth': 1, 'gamma': 19, 'max_delta_step': 5, 'min_child_weight': 14, 'learning_rate': 0.31239936501332155, 'subsample': 0.520547953156633, 'n_estimators': 141}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:21,040] Trial 7 finished with value: 0.13193749951160016 and parameters: {'max_depth': 4, 'gamma': 20, 'max_delta_step': 16, 'min_child_weight': 19, 'learning_rate': 0.8949325230772212, 'subsample': 0.598302078832274, 'n_estimators': 232}. Best is trial 2 with value: 0.260143188084316.
# [I 2025-02-26 01:33:23,312] Trial 8 finished with value: 0.38730498109347955 and parameters: {'max_depth': 2, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.3892886123997925, 'subsample': 0.272077682742122, 'n_estimators': 209}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:25,061] Trial 9 finished with value: -495.90773867046937 and parameters: {'max_depth': 8, 'gamma': 5, 'max_delta_step': 11, 'min_child_weight': 3, 'learning_rate': 0.8023947837732857, 'subsample': 0.07547609303609105, 'n_estimators': 247}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:26,076] Trial 10 finished with value: 0.15735633518688152 and parameters: {'max_depth': 11, 'gamma': 11, 'max_delta_step': 20, 'min_child_weight': 7, 'learning_rate': 0.6404484139650889, 'subsample': 0.380912667291559, 'n_estimators': 186}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:27,969] Trial 11 finished with value: -0.22806264144744404 and parameters: {'max_depth': 6, 'gamma': 0, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.4592156358638099, 'subsample': 0.3209978815432278, 'n_estimators': 189}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:29,722] Trial 12 finished with value: 0.24284655363786412 and parameters: {'max_depth': 1, 'gamma': 3, 'max_delta_step': 6, 'min_child_weight': 8, 'learning_rate': 0.281789689556585, 'subsample': 0.35780805412413363, 'n_estimators': 182}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:31,352] Trial 13 finished with value: -0.0023560455906403988 and parameters: {'max_depth': 5, 'gamma': 9, 'max_delta_step': 3, 'min_child_weight': 18, 'learning_rate': 0.5813766248511165, 'subsample': 0.010285859930709018, 'n_estimators': 92}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:37,281] Trial 14 finished with value: 0.2666820540200918 and parameters: {'max_depth': 14, 'gamma': 3, 'max_delta_step': 8, 'min_child_weight': 10, 'learning_rate': 0.34181880608212867, 'subsample': 0.6637430221833706, 'n_estimators': 205}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:38,021] Trial 15 finished with value: 0.21254234784624726 and parameters: {'max_depth': 14, 'gamma': 15, 'max_delta_step': 9, 'min_child_weight': 5, 'learning_rate': 0.28971638633403207, 'subsample': 0.6869682431421172, 'n_estimators': 218}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:39,860] Trial 16 finished with value: 0.24928154980691497 and parameters: {'max_depth': 15, 'gamma': 8, 'max_delta_step': 0, 'min_child_weight': 16, 'learning_rate': 0.1940259064196469, 'subsample': 0.7001277651679781, 'n_estimators': 205}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:41,439] Trial 17 finished with value: 0.257722658053545 and parameters: {'max_depth': 9, 'gamma': 3, 'max_delta_step': 9, 'min_child_weight': 9, 'learning_rate': 0.5999023364186625, 'subsample': 0.49466678192202224, 'n_estimators': 164}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:46,856] Trial 18 finished with value: 0.058308326932698495 and parameters: {'max_depth': 20, 'gamma': 14, 'max_delta_step': 3, 'min_child_weight': 6, 'learning_rate': 0.0031172359112078274, 'subsample': 0.8070973172548928, 'n_estimators': 96}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:50,308] Trial 19 finished with value: 0.16656079632283882 and parameters: {'max_depth': 13, 'gamma': 2, 'max_delta_step': 19, 'min_child_weight': 13, 'learning_rate': 0.36427317122477376, 'subsample': 0.4567482981494164, 'n_estimators': 213}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:51,477] Trial 20 finished with value: 0.25067449854043133 and parameters: {'max_depth': 16, 'gamma': 7, 'max_delta_step': 8, 'min_child_weight': 2, 'learning_rate': 0.18398902319991736, 'subsample': 0.5745600339519261, 'n_estimators': 107}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:52,722] Trial 21 finished with value: 0.29303653698937326 and parameters: {'max_depth': 3, 'gamma': 4, 'max_delta_step': 5, 'min_child_weight': 11, 'learning_rate': 0.4046677148942253, 'subsample': 0.26163904204055133, 'n_estimators': 166}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:53,505] Trial 22 finished with value: 0.3160193315582851 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 10, 'learning_rate': 0.5258708676042735, 'subsample': 0.25522532391532704, 'n_estimators': 162}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:55,043] Trial 23 finished with value: 0.25428918486720853 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 9, 'learning_rate': 0.5246818210230351, 'subsample': 0.24664554221227797, 'n_estimators': 162}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:55,985] Trial 24 finished with value: 0.02323865567226624 and parameters: {'max_depth': 6, 'gamma': 1, 'max_delta_step': 1, 'min_child_weight': 16, 'learning_rate': 0.6703967662007588, 'subsample': 0.400823151900466, 'n_estimators': 175}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:33:57,108] Trial 25 finished with value: 0.07364681877442458 and parameters: {'max_depth': 3, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 12, 'learning_rate': 0.708700871200737, 'subsample': 0.24261204600911335, 'n_estimators': 145}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:02,471] Trial 26 finished with value: 0.22415405207771932 and parameters: {'max_depth': 1, 'gamma': 9, 'max_delta_step': 5, 'min_child_weight': 8, 'learning_rate': 0.5068812265986307, 'subsample': 0.02970848138416332, 'n_estimators': 115}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:04,028] Trial 27 finished with value: 0.22366069277260703 and parameters: {'max_depth': 6, 'gamma': 4, 'max_delta_step': 2, 'min_child_weight': 5, 'learning_rate': 0.38485904622049705, 'subsample': 0.1576843358976195, 'n_estimators': 196}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:05,371] Trial 28 finished with value: 0.32398431869503086 and parameters: {'max_depth': 3, 'gamma': 7, 'max_delta_step': 4, 'min_child_weight': 11, 'learning_rate': 0.5558195632004521, 'subsample': 0.27058035429729393, 'n_estimators': 225}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:06,894] Trial 29 finished with value: 0.29660357104323365 and parameters: {'max_depth': 9, 'gamma': 7, 'max_delta_step': 0, 'min_child_weight': 12, 'learning_rate': 0.5540629033888379, 'subsample': 0.1598969291667291, 'n_estimators': 225}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:10,528] Trial 30 finished with value: 0.2504878559407768 and parameters: {'max_depth': 7, 'gamma': 10, 'max_delta_step': 3, 'min_child_weight': 14, 'learning_rate': 0.7034553019586633, 'subsample': 0.43279646176888587, 'n_estimators': 15}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:12,025] Trial 31 finished with value: 0.33466241919483486 and parameters: {'max_depth': 9, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 12, 'learning_rate': 0.5575650476267656, 'subsample': 0.1594311487208509, 'n_estimators': 226}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:15,449] Trial 32 finished with value: 0.17548058060648375 and parameters: {'max_depth': 4, 'gamma': 8, 'max_delta_step': 1, 'min_child_weight': 9, 'learning_rate': 0.485072249031238, 'subsample': 0.18720969080647393, 'n_estimators': 43}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:17,302] Trial 33 finished with value: 0.13927463585006472 and parameters: {'max_depth': 2, 'gamma': 12, 'max_delta_step': 4, 'min_child_weight': 16, 'learning_rate': 0.60009364579908, 'subsample': 0.08769605704300226, 'n_estimators': 228}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:18,367] Trial 34 finished with value: 0.34274678518458623 and parameters: {'max_depth': 5, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 11, 'learning_rate': 0.7452408410898156, 'subsample': 0.3164994680541074, 'n_estimators': 247}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:19,884] Trial 35 finished with value: 0.13107915294226913 and parameters: {'max_depth': 5, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 13, 'learning_rate': 0.7926267771064219, 'subsample': 0.3254054720970691, 'n_estimators': 249}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:21,146] Trial 36 finished with value: 0.23964887247356637 and parameters: {'max_depth': 10, 'gamma': 11, 'max_delta_step': 0, 'min_child_weight': 11, 'learning_rate': 0.8883554946045611, 'subsample': 0.19468690487310825, 'n_estimators': 236}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:27,241] Trial 37 finished with value: 0.11262840357729276 and parameters: {'max_depth': 7, 'gamma': 6, 'max_delta_step': 2, 'min_child_weight': 13, 'learning_rate': 0.9488780644123292, 'subsample': 0.29811358173343927, 'n_estimators': 214}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:29,322] Trial 38 finished with value: 0.3256262454111011 and parameters: {'max_depth': 5, 'gamma': 9, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.7379107978644567, 'subsample': 0.1329301147384, 'n_estimators': 233}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:30,725] Trial 39 finished with value: -0.02567537457030844 and parameters: {'max_depth': 8, 'gamma': 15, 'max_delta_step': 14, 'min_child_weight': 7, 'learning_rate': 0.7423408331675522, 'subsample': 0.09760209612372056, 'n_estimators': 237}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:32,293] Trial 40 finished with value: 0.04759391376735922 and parameters: {'max_depth': 5, 'gamma': 9, 'max_delta_step': 6, 'min_child_weight': 4, 'learning_rate': 0.8673022268719841, 'subsample': 0.13373151951300388, 'n_estimators': 249}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:33,904] Trial 41 finished with value: 0.18607719964835523 and parameters: {'max_depth': 4, 'gamma': 8, 'max_delta_step': 1, 'min_child_weight': 12, 'learning_rate': 0.65152021038941, 'subsample': 0.20454573217299576, 'n_estimators': 223}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:36,235] Trial 42 finished with value: 0.20243776542120773 and parameters: {'max_depth': 3, 'gamma': 10, 'max_delta_step': 3, 'min_child_weight': 8, 'learning_rate': 0.7600832500797359, 'subsample': 0.319587931252441, 'n_estimators': 203}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:38,448] Trial 43 finished with value: -0.033673752283609915 and parameters: {'max_depth': 7, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 10, 'learning_rate': 0.8357926413208197, 'subsample': 0.9798654261279622, 'n_estimators': 235}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:41,081] Trial 44 finished with value: -0.25911193253984477 and parameters: {'max_depth': 11, 'gamma': 7, 'max_delta_step': 2, 'min_child_weight': 6, 'learning_rate': 0.998642291626727, 'subsample': 0.04729043291114966, 'n_estimators': 215}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:43,158] Trial 45 finished with value: 0.20011180842078968 and parameters: {'max_depth': 4, 'gamma': 13, 'max_delta_step': 1, 'min_child_weight': 15, 'learning_rate': 0.24638763632401184, 'subsample': 0.3636390365428483, 'n_estimators': 197}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:45,333] Trial 46 finished with value: 0.19107702522792025 and parameters: {'max_depth': 2, 'gamma': 10, 'max_delta_step': 12, 'min_child_weight': 9, 'learning_rate': 0.4328755847110661, 'subsample': 0.11487648759337502, 'n_estimators': 241}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:46,755] Trial 47 finished with value: -0.22160612514059586 and parameters: {'max_depth': 5, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 11, 'learning_rate': 0.6277060466809338, 'subsample': 0.21693757573773426, 'n_estimators': 227}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:47,728] Trial 48 finished with value: 0.3174030563534852 and parameters: {'max_depth': 1, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.6976054534432407, 'subsample': 0.28359660463348935, 'n_estimators': 182}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:50,067] Trial 49 finished with value: -2.0097897375241827 and parameters: {'max_depth': 8, 'gamma': 2, 'max_delta_step': 4, 'min_child_weight': 10, 'learning_rate': 0.736287268496904, 'subsample': 0.16778257092211887, 'n_estimators': 193}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:50,717] Trial 50 finished with value: 0.027467875795462282 and parameters: {'max_depth': 6, 'gamma': 8, 'max_delta_step': 6, 'min_child_weight': 7, 'learning_rate': 0.46551955154422553, 'subsample': 0.04890229422800432, 'n_estimators': 75}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:52,362] Trial 51 finished with value: 0.3019956097887001 and parameters: {'max_depth': 1, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 4, 'learning_rate': 0.6917708352122615, 'subsample': 0.3020526913462565, 'n_estimators': 211}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:54,946] Trial 52 finished with value: 0.040620265104572506 and parameters: {'max_depth': 3, 'gamma': 7, 'max_delta_step': 2, 'min_child_weight': 8, 'learning_rate': 0.8324383943281377, 'subsample': 0.40698754368490014, 'n_estimators': 241}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:34:57,674] Trial 53 finished with value: 0.18368766776629442 and parameters: {'max_depth': 1, 'gamma': 9, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.5614787215227438, 'subsample': 0.36212852710620735, 'n_estimators': 182}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:01,770] Trial 54 finished with value: 0.3574481094125257 and parameters: {'max_depth': 2, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.6334866980957304, 'subsample': 0.26633136589112616, 'n_estimators': 222}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:03,696] Trial 55 finished with value: 0.19733428821752408 and parameters: {'max_depth': 3, 'gamma': 4, 'max_delta_step': 16, 'min_child_weight': 9, 'learning_rate': 0.6392218049300189, 'subsample': 0.47849741735942, 'n_estimators': 221}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:05,814] Trial 56 finished with value: 0.23160534493224216 and parameters: {'max_depth': 5, 'gamma': 8, 'max_delta_step': 2, 'min_child_weight': 11, 'learning_rate': 0.583122253286199, 'subsample': 0.22380551019457723, 'n_estimators': 231}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:09,120] Trial 57 finished with value: 0.19442476293159683 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.6211518591053953, 'subsample': 0.1327865989920658, 'n_estimators': 206}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:09,679] Trial 58 finished with value: 0.009111870607339978 and parameters: {'max_depth': 12, 'gamma': 2, 'max_delta_step': 7, 'min_child_weight': 7, 'learning_rate': 0.5507999355551573, 'subsample': 0.26356760288070896, 'n_estimators': 249}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:10,261] Trial 59 finished with value: 0.27251019886894456 and parameters: {'max_depth': 4, 'gamma': 6, 'max_delta_step': 3, 'min_child_weight': 12, 'learning_rate': 0.32366054300778774, 'subsample': 0.5365857213454571, 'n_estimators': 150}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:12,165] Trial 60 finished with value: 0.26801786187544163 and parameters: {'max_depth': 3, 'gamma': 9, 'max_delta_step': 5, 'min_child_weight': 20, 'learning_rate': 0.7611683214665861, 'subsample': 0.35397178379300176, 'n_estimators': 220}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:16,087] Trial 61 finished with value: 0.25457983725424804 and parameters: {'max_depth': 1, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 5, 'learning_rate': 0.6779161672181083, 'subsample': 0.2596591525169315, 'n_estimators': 202}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:20,119] Trial 62 finished with value: 0.2465297421073418 and parameters: {'max_depth': 2, 'gamma': 18, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.7253425848773721, 'subsample': 0.3375833315434409, 'n_estimators': 231}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:23,258] Trial 63 finished with value: -0.06334929744594153 and parameters: {'max_depth': 4, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 3, 'learning_rate': 0.8110064882657733, 'subsample': 0.2805184913805162, 'n_estimators': 243}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:25,352] Trial 64 finished with value: 0.2326102123753594 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 10, 'learning_rate': 0.675492533549178, 'subsample': 0.394286303723593, 'n_estimators': 172}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:27,153] Trial 65 finished with value: 0.24669497736296508 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.5006692555655295, 'subsample': 0.22937165102681734, 'n_estimators': 183}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:28,422] Trial 66 finished with value: 0.2055334017867958 and parameters: {'max_depth': 1, 'gamma': 8, 'max_delta_step': 1, 'min_child_weight': 13, 'learning_rate': 0.4077472702652825, 'subsample': 0.1867945160246413, 'n_estimators': 211}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:36,641] Trial 67 finished with value: -0.06744031184019916 and parameters: {'max_depth': 9, 'gamma': 11, 'max_delta_step': 0, 'min_child_weight': 1, 'learning_rate': 0.533943987772867, 'subsample': 0.00495670610212387, 'n_estimators': 190}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:38,902] Trial 68 finished with value: 0.15579850748459645 and parameters: {'max_depth': 6, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 5, 'learning_rate': 0.6148745126658273, 'subsample': 0.8731719852875809, 'n_estimators': 220}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:40,765] Trial 69 finished with value: 0.2877935986710807 and parameters: {'max_depth': 3, 'gamma': 5, 'max_delta_step': 10, 'min_child_weight': 9, 'learning_rate': 0.4699481760447766, 'subsample': 0.4345792557372679, 'n_estimators': 131}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:42,931] Trial 70 finished with value: 0.17757105039185284 and parameters: {'max_depth': 5, 'gamma': 7, 'max_delta_step': 4, 'min_child_weight': 14, 'learning_rate': 0.7710606967153859, 'subsample': 0.29021754791885385, 'n_estimators': 230}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:44,753] Trial 71 finished with value: 0.15290000935963577 and parameters: {'max_depth': 2, 'gamma': 6, 'max_delta_step': 2, 'min_child_weight': 11, 'learning_rate': 0.5106054598751838, 'subsample': 0.2370456191463503, 'n_estimators': 200}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:48,915] Trial 72 finished with value: 0.08981418929236629 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 10, 'learning_rate': 0.5749078253394586, 'subsample': 0.17316478679843944, 'n_estimators': 158}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:50,812] Trial 73 finished with value: -0.48873820666004253 and parameters: {'max_depth': 4, 'gamma': 3, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.6543841430606101, 'subsample': 0.13292771253269975, 'n_estimators': 208}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:54,474] Trial 74 finished with value: 0.033174498927111884 and parameters: {'max_depth': 1, 'gamma': 8, 'max_delta_step': 0, 'min_child_weight': 12, 'learning_rate': 0.3611481488896883, 'subsample': 0.0768705751097688, 'n_estimators': 172}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:56,204] Trial 75 finished with value: 0.24373616712628088 and parameters: {'max_depth': 3, 'gamma': 5, 'max_delta_step': 7, 'min_child_weight': 6, 'learning_rate': 0.0915114792638152, 'subsample': 0.27656317662263574, 'n_estimators': 138}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:56,942] Trial 76 finished with value: 0.26350907795040446 and parameters: {'max_depth': 1, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 10, 'learning_rate': 0.5325182082668832, 'subsample': 0.3117794522463573, 'n_estimators': 118}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:35:57,720] Trial 77 finished with value: 0.22412566988223703 and parameters: {'max_depth': 2, 'gamma': 9, 'max_delta_step': 5, 'min_child_weight': 8, 'learning_rate': 0.7170853479701224, 'subsample': 0.21003973425423883, 'n_estimators': 238}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:00,582] Trial 78 finished with value: -1.152770670665333 and parameters: {'max_depth': 4, 'gamma': 1, 'max_delta_step': 8, 'min_child_weight': 9, 'learning_rate': 0.5966600799694373, 'subsample': 0.151996461917265, 'n_estimators': 216}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:02,494] Trial 79 finished with value: 0.19120726526009402 and parameters: {'max_depth': 7, 'gamma': 6, 'max_delta_step': 2, 'min_child_weight': 13, 'learning_rate': 0.41159213343173556, 'subsample': 0.10353688044333498, 'n_estimators': 150}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:03,682] Trial 80 finished with value: 0.38509282684384016 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.4484827296419194, 'subsample': 0.24386949589060083, 'n_estimators': 188}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:04,114] Trial 81 finished with value: 0.33266872080688514 and parameters: {'max_depth': 16, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.4494397876856584, 'subsample': 0.25628458944175425, 'n_estimators': 192}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:04,562] Trial 82 finished with value: 0.27303687698504886 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 6, 'learning_rate': 0.45018154636942914, 'subsample': 0.24905843892646468, 'n_estimators': 191}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:07,916] Trial 83 finished with value: 0.2716205391087094 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.38664517761780925, 'subsample': 0.29497040935272006, 'n_estimators': 178}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:11,562] Trial 84 finished with value: 0.3151436670340363 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 4, 'learning_rate': 0.4819767960025199, 'subsample': 0.19119790204221915, 'n_estimators': 197}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:13,256] Trial 85 finished with value: 0.20557340260048373 and parameters: {'max_depth': 15, 'gamma': 2, 'max_delta_step': 3, 'min_child_weight': 5, 'learning_rate': 0.45251721058112476, 'subsample': 0.3443012143599497, 'n_estimators': 243}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:14,917] Trial 86 finished with value: 0.2588485378182881 and parameters: {'max_depth': 20, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.26732280860124413, 'subsample': 0.32401610116967694, 'n_estimators': 225}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:20,246] Trial 87 finished with value: 0.06506196724951463 and parameters: {'max_depth': 19, 'gamma': 1, 'max_delta_step': 2, 'min_child_weight': 8, 'learning_rate': 0.3420092841519742, 'subsample': 0.2140952151393487, 'n_estimators': 186}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:22,539] Trial 88 finished with value: 0.1992575462988848 and parameters: {'max_depth': 10, 'gamma': 7, 'max_delta_step': 4, 'min_child_weight': 6, 'learning_rate': 0.6980345267322527, 'subsample': 0.6387701754288311, 'n_estimators': 234}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:25,391] Trial 89 finished with value: 0.30992369890478433 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 18, 'min_child_weight': 7, 'learning_rate': 0.42477789671444177, 'subsample': 0.3853904319417083, 'n_estimators': 224}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:27,956] Trial 90 finished with value: -0.07138209248985627 and parameters: {'max_depth': 13, 'gamma': 8, 'max_delta_step': 0, 'min_child_weight': 9, 'learning_rate': 0.6636498826842451, 'subsample': 0.14943616195356946, 'n_estimators': 210}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:35,372] Trial 91 finished with value: -0.012581867532036606 and parameters: {'max_depth': 15, 'gamma': 4, 'max_delta_step': 6, 'min_child_weight': 11, 'learning_rate': 0.5472567483926882, 'subsample': 0.2649667212067305, 'n_estimators': 167}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:37,011] Trial 92 finished with value: 0.16424688137509347 and parameters: {'max_depth': 16, 'gamma': 6, 'max_delta_step': 3, 'min_child_weight': 12, 'learning_rate': 0.5060410083713112, 'subsample': 0.2304368368292684, 'n_estimators': 216}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:38,580] Trial 93 finished with value: 0.028884616585784784 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 9, 'learning_rate': 0.7445459869177862, 'subsample': 0.18000977583270444, 'n_estimators': 178}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:40,105] Trial 94 finished with value: 0.16536907712712212 and parameters: {'max_depth': 3, 'gamma': 6, 'max_delta_step': 5, 'min_child_weight': 5, 'learning_rate': 0.6091564067197723, 'subsample': 0.25441309987600613, 'n_estimators': 204}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:41,497] Trial 95 finished with value: 0.2697405911952011 and parameters: {'max_depth': 18, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 10, 'learning_rate': 0.5773618689854314, 'subsample': 0.29894757856277515, 'n_estimators': 194}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:43,165] Trial 96 finished with value: 0.040427343444805475 and parameters: {'max_depth': 14, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 8, 'learning_rate': 0.38348525512148746, 'subsample': 0.05783976702830229, 'n_estimators': 186}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:44,331] Trial 97 finished with value: 0.33622491533219634 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.48604296051892826, 'subsample': 0.27839127506316413, 'n_estimators': 41}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:45,652] Trial 98 finished with value: 0.3266348344605733 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.6389118044372769, 'subsample': 0.27910967297107536, 'n_estimators': 58}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:49,825] Trial 99 finished with value: 0.21558075802821475 and parameters: {'max_depth': 12, 'gamma': 3, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.48224559914848786, 'subsample': 0.3331391859310121, 'n_estimators': 30}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:51,753] Trial 100 finished with value: -0.00208724257914783 and parameters: {'max_depth': 1, 'gamma': 2, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.6385463588008355, 'subsample': 0.20561545070409454, 'n_estimators': 49}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:53,143] Trial 101 finished with value: 0.35871620807470983 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.6869839211956275, 'subsample': 0.2764194723655341, 'n_estimators': 66}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:54,492] Trial 102 finished with value: 0.2632528861645428 and parameters: {'max_depth': 2, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.42934605306361634, 'subsample': 0.23677146282879713, 'n_estimators': 72}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:36:55,600] Trial 103 finished with value: 0.09193153540322385 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.7837155901231855, 'subsample': 0.31473719582565995, 'n_estimators': 28}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:02,018] Trial 104 finished with value: 0.38180570581907536 and parameters: {'max_depth': 1, 'gamma': 2, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.56197676798897, 'subsample': 0.2732749683635556, 'n_estimators': 45}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:06,619] Trial 105 finished with value: 0.057014883862045784 and parameters: {'max_depth': 1, 'gamma': 2, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.685013870148032, 'subsample': 0.36581392804304436, 'n_estimators': 47}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:08,504] Trial 106 finished with value: -0.38419457647560495 and parameters: {'max_depth': 9, 'gamma': 0, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.6323952434469219, 'subsample': 0.2811454799564055, 'n_estimators': 55}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:09,397] Trial 107 finished with value: 0.23231870818943445 and parameters: {'max_depth': 1, 'gamma': 3, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.5139979977720662, 'subsample': 0.24986913262705385, 'n_estimators': 68}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:10,493] Trial 108 finished with value: 0.2794558044878147 and parameters: {'max_depth': 2, 'gamma': 1, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.5940060854437397, 'subsample': 0.41221462978914125, 'n_estimators': 38}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:11,445] Trial 109 finished with value: 0.07282033263544407 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.5601549746834085, 'subsample': 0.15913315078290335, 'n_estimators': 63}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:12,161] Trial 110 finished with value: -0.10024746871266355 and parameters: {'max_depth': 10, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 5, 'learning_rate': 0.6506719616818379, 'subsample': 0.11142723721465533, 'n_estimators': 97}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:12,949] Trial 111 finished with value: 0.23224033394845278 and parameters: {'max_depth': 3, 'gamma': 2, 'max_delta_step': 2, 'min_child_weight': 11, 'learning_rate': 0.5300645647880083, 'subsample': 0.26947858672940306, 'n_estimators': 13}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:20,041] Trial 112 finished with value: 0.23006360392459602 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.4696176874019439, 'subsample': 0.3121937259892846, 'n_estimators': 38}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:21,697] Trial 113 finished with value: 0.1124970479767039 and parameters: {'max_depth': 1, 'gamma': 9, 'max_delta_step': 2, 'min_child_weight': 12, 'learning_rate': 0.8120039351195647, 'subsample': 0.7622777434729351, 'n_estimators': 56}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:22,487] Trial 114 finished with value: 0.12832283717052273 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 9, 'learning_rate': 0.7247943787797888, 'subsample': 0.21351473381115912, 'n_estimators': 87}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:24,146] Trial 115 finished with value: 0.11498611321441055 and parameters: {'max_depth': 6, 'gamma': 4, 'max_delta_step': 14, 'min_child_weight': 6, 'learning_rate': 0.5629926344038243, 'subsample': 0.2758031877872089, 'n_estimators': 81}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:28,615] Trial 116 finished with value: 0.2345515545114949 and parameters: {'max_depth': 3, 'gamma': 11, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.6192423195124835, 'subsample': 0.22691538037793907, 'n_estimators': 56}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:29,992] Trial 117 finished with value: 0.31007032304865667 and parameters: {'max_depth': 2, 'gamma': 1, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.44011755009840836, 'subsample': 0.3441072342529923, 'n_estimators': 33}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:31,839] Trial 118 finished with value: 0.23462760610179234 and parameters: {'max_depth': 3, 'gamma': 5, 'max_delta_step': 3, 'min_child_weight': 6, 'learning_rate': 0.4961683689663413, 'subsample': 0.37269961187867584, 'n_estimators': 244}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:33,905] Trial 119 finished with value: 0.14828391641605287 and parameters: {'max_depth': 5, 'gamma': 7, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.3921751153663502, 'subsample': 0.19054195574529972, 'n_estimators': 45}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:36,032] Trial 120 finished with value: 0.201866524397731 and parameters: {'max_depth': 11, 'gamma': 18, 'max_delta_step': 0, 'min_child_weight': 9, 'learning_rate': 0.5464114000511988, 'subsample': 0.29972470283976893, 'n_estimators': 228}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:38,583] Trial 121 finished with value: 0.2227572320821969 and parameters: {'max_depth': 1, 'gamma': 8, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.6975815528216708, 'subsample': 0.2886395257258571, 'n_estimators': 238}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:40,425] Trial 122 finished with value: 0.2548566250532992 and parameters: {'max_depth': 2, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.750342986859609, 'subsample': 0.25633495997272376, 'n_estimators': 20}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:41,639] Trial 123 finished with value: 0.08118723169288589 and parameters: {'max_depth': 1, 'gamma': 7, 'max_delta_step': 0, 'min_child_weight': 4, 'learning_rate': 0.6719888380650778, 'subsample': 0.32915107348475, 'n_estimators': 51}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:43,413] Trial 124 finished with value: 0.14726156273962587 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 5, 'learning_rate': 0.36099822616074984, 'subsample': 0.23787559640607983, 'n_estimators': 39}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:44,396] Trial 125 finished with value: 0.19229139350233948 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.5840847944752321, 'subsample': 0.2772900339238968, 'n_estimators': 61}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:46,525] Trial 126 finished with value: 0.14694157515773854 and parameters: {'max_depth': 4, 'gamma': 10, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.7134291117031346, 'subsample': 0.20248317748278422, 'n_estimators': 232}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:51,192] Trial 127 finished with value: 0.1354511012450933 and parameters: {'max_depth': 8, 'gamma': 12, 'max_delta_step': 2, 'min_child_weight': 11, 'learning_rate': 0.6578695924667594, 'subsample': 0.17212062637529574, 'n_estimators': 213}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:53,750] Trial 128 finished with value: 0.20592747054040883 and parameters: {'max_depth': 2, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 12, 'learning_rate': 0.7723831616089053, 'subsample': 0.2998038390274726, 'n_estimators': 222}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:37:59,587] Trial 129 finished with value: 0.19639713318421437 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 3, 'min_child_weight': 8, 'learning_rate': 0.6108207675564169, 'subsample': 0.25282225064020064, 'n_estimators': 249}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:01,692] Trial 130 finished with value: -0.7676748654725003 and parameters: {'max_depth': 7, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.7371875181690244, 'subsample': 0.13696959748029458, 'n_estimators': 120}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:04,032] Trial 131 finished with value: 0.3132560287936498 and parameters: {'max_depth': 3, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 10, 'learning_rate': 0.5193724807343589, 'subsample': 0.22475550440475708, 'n_estimators': 161}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:05,552] Trial 132 finished with value: 0.22496671725228767 and parameters: {'max_depth': 2, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 11, 'learning_rate': 0.48794355213331886, 'subsample': 0.26391009741833477, 'n_estimators': 198}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:14,061] Trial 133 finished with value: 0.24570836865406243 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 6, 'learning_rate': 0.46254255192859617, 'subsample': 0.32159505932850313, 'n_estimators': 218}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:16,183] Trial 134 finished with value: 0.2027212753234625 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 5, 'min_child_weight': 8, 'learning_rate': 0.4180903612441301, 'subsample': 0.2873931453690341, 'n_estimators': 175}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:17,742] Trial 135 finished with value: 0.21608417216591091 and parameters: {'max_depth': 4, 'gamma': 7, 'max_delta_step': 3, 'min_child_weight': 18, 'learning_rate': 0.534153201847791, 'subsample': 0.3513155454773619, 'n_estimators': 203}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:18,795] Trial 136 finished with value: 0.3149708941728303 and parameters: {'max_depth': 3, 'gamma': 6, 'max_delta_step': 2, 'min_child_weight': 9, 'learning_rate': 0.686138444064047, 'subsample': 0.24469248471027144, 'n_estimators': 209}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:19,685] Trial 137 finished with value: 0.25219466557549863 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 10, 'learning_rate': 0.6331569782991896, 'subsample': 0.3125269256065194, 'n_estimators': 169}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:20,359] Trial 138 finished with value: 0.35826290443483955 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5711721773546138, 'subsample': 0.27559833331539596, 'n_estimators': 191}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:20,976] Trial 139 finished with value: 0.3306861702017123 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5937532696335649, 'subsample': 0.27794202093476494, 'n_estimators': 189}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:22,124] Trial 140 finished with value: 0.10826495660346025 and parameters: {'max_depth': 18, 'gamma': 3, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.573429935066694, 'subsample': 0.26596428893006485, 'n_estimators': 237}. Best is trial 8 with value: 0.38730498109347955.
# [I 2025-02-26 01:38:24,330] Trial 141 finished with value: 0.4317497433622448 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5951214841506621, 'subsample': 0.2834638087754667, 'n_estimators': 184}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:25,837] Trial 142 finished with value: 0.11032653720932384 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.6032633038883894, 'subsample': 0.2348308775731653, 'n_estimators': 184}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:27,494] Trial 143 finished with value: 0.3658673066242145 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5955535762312182, 'subsample': 0.29604989512552954, 'n_estimators': 194}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:29,358] Trial 144 finished with value: 0.23100203110366213 and parameters: {'max_depth': 18, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.5740822976713201, 'subsample': 0.3315657071466594, 'n_estimators': 191}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:35,828] Trial 145 finished with value: 0.31582916714945486 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5892971545319435, 'subsample': 0.29813031124154077, 'n_estimators': 194}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:37,589] Trial 146 finished with value: 0.09746381931067394 and parameters: {'max_depth': 19, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.6268832145937435, 'subsample': 0.2771364154467601, 'n_estimators': 188}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:39,041] Trial 147 finished with value: 0.29310418856800213 and parameters: {'max_depth': 20, 'gamma': 6, 'max_delta_step': 11, 'min_child_weight': 7, 'learning_rate': 0.6485011060564964, 'subsample': 0.21180404742990305, 'n_estimators': 198}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:39,918] Trial 148 finished with value: 0.10167074289983702 and parameters: {'max_depth': 18, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.5405281271387974, 'subsample': 0.34858974702710727, 'n_estimators': 180}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:40,766] Trial 149 finished with value: 0.2019404690864368 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.6010778793883301, 'subsample': 0.5398132055363464, 'n_estimators': 205}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:41,867] Trial 150 finished with value: 0.23328660426321923 and parameters: {'max_depth': 20, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.5672907128578162, 'subsample': 0.30024429904521066, 'n_estimators': 43}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:47,773] Trial 151 finished with value: 0.35575105932122975 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.5192328411951392, 'subsample': 0.24741270144762387, 'n_estimators': 227}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:50,295] Trial 152 finished with value: 0.33234422140721476 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.5083470522859698, 'subsample': 0.2495928209224164, 'n_estimators': 229}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:38:54,131] Trial 153 finished with value: 0.29817202196888704 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 5, 'learning_rate': 0.5016855636201242, 'subsample': 0.24682011020238914, 'n_estimators': 189}. Best is trial 141 with value: 0.4317497433622448.
# ...
# [I 2025-02-26 01:52:52,681] Trial 450 finished with value: -0.22923445715107915 and parameters: {'max_depth': 10, 'gamma': 2, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.5511705596947171, 'subsample': 0.2950601260627569, 'n_estimators': 190}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:52:54,494] Trial 451 finished with value: 0.3654155778864855 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.46036607393603696, 'subsample': 0.27991690473385705, 'n_estimators': 234}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:52:55,612] Trial 452 finished with value: 0.07387895982079351 and parameters: {'max_depth': 17, 'gamma': 1, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.46011460474983895, 'subsample': 0.2746981269427782, 'n_estimators': 233}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:52:57,965] Trial 453 finished with value: 0.33552954810753755 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 7, 'learning_rate': 0.4634044247751656, 'subsample': 0.24754721753990405, 'n_estimators': 236}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:52:59,540] Trial 454 finished with value: 0.3027313743915393 and parameters: {'max_depth': 16, 'gamma': 5, 'max_delta_step': 4, 'min_child_weight': 6, 'learning_rate': 0.488956671402382, 'subsample': 0.2146811375712449, 'n_estimators': 230}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:01,914] Trial 455 finished with value: 0.23909548254266577 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 8, 'learning_rate': 0.4521372583899953, 'subsample': 0.2779631300627198, 'n_estimators': 221}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:03,691] Trial 456 finished with value: 0.26142766473774015 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.5144464502799307, 'subsample': 0.23297411778641158, 'n_estimators': 229}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:13,537] Trial 457 finished with value: 0.129366528636363 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 6, 'learning_rate': 0.6677295358523391, 'subsample': 0.2571858504550554, 'n_estimators': 217}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:15,372] Trial 458 finished with value: 0.2109789258344572 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 2, 'min_child_weight': 8, 'learning_rate': 0.48057438746553377, 'subsample': 0.30991671902385687, 'n_estimators': 49}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:17,502] Trial 459 finished with value: 0.21123812868594694 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.49361293171211584, 'subsample': 0.2877779223483734, 'n_estimators': 90}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:19,746] Trial 460 finished with value: 0.26829892119747034 and parameters: {'max_depth': 14, 'gamma': 4, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.5311005881753147, 'subsample': 0.2600923484467332, 'n_estimators': 201}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:20,864] Trial 461 finished with value: 0.09182649786850794 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 9, 'learning_rate': 0.5656454938786325, 'subsample': 0.23738456783990738, 'n_estimators': 225}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:22,575] Trial 462 finished with value: 0.3082881357803119 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 6, 'learning_rate': 0.5045340052485842, 'subsample': 0.2777292459851412, 'n_estimators': 120}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:24,396] Trial 463 finished with value: 0.20066312275270848 and parameters: {'max_depth': 19, 'gamma': 11, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.4448866946828937, 'subsample': 0.3434122307069237, 'n_estimators': 208}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:26,139] Trial 464 finished with value: 0.26309693089224284 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 5, 'min_child_weight': 7, 'learning_rate': 0.5905614967337953, 'subsample': 0.2992534412418442, 'n_estimators': 214}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:27,651] Trial 465 finished with value: -0.08721240432138155 and parameters: {'max_depth': 16, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.5414543195727128, 'subsample': 0.2057361787929603, 'n_estimators': 194}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:29,544] Trial 466 finished with value: 0.32921815004971566 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.5742808391296828, 'subsample': 0.25434605033352353, 'n_estimators': 235}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:31,552] Trial 467 finished with value: 0.2582400899183781 and parameters: {'max_depth': 18, 'gamma': 6, 'max_delta_step': 3, 'min_child_weight': 5, 'learning_rate': 0.6420624462018414, 'subsample': 0.2250576380455239, 'n_estimators': 185}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:34,508] Trial 468 finished with value: 0.3130011885744901 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.515841718524353, 'subsample': 0.2705297007738284, 'n_estimators': 198}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:37,187] Trial 469 finished with value: 0.1999422825363566 and parameters: {'max_depth': 17, 'gamma': 3, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.4641289127012699, 'subsample': 0.32000288382018083, 'n_estimators': 130}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:39,232] Trial 470 finished with value: 0.25417087720089493 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.5583905321908919, 'subsample': 0.241881348813944, 'n_estimators': 229}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:46,472] Trial 471 finished with value: 0.16050672008575284 and parameters: {'max_depth': 16, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.6041916153844057, 'subsample': 0.28163193749751836, 'n_estimators': 238}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:48,668] Trial 472 finished with value: 0.2963799899559736 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.5392086423082267, 'subsample': 0.7196981030124696, 'n_estimators': 106}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:51,853] Trial 473 finished with value: 0.2102970442864246 and parameters: {'max_depth': 18, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.48399323145109197, 'subsample': 0.299597115574755, 'n_estimators': 176}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:53:54,592] Trial 474 finished with value: 0.139891968020747 and parameters: {'max_depth': 20, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.6231648360783558, 'subsample': 0.2580349195300333, 'n_estimators': 220}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:02,269] Trial 475 finished with value: 0.13820205609623382 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.6788730445731682, 'subsample': 0.18213866639271242, 'n_estimators': 48}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:03,953] Trial 476 finished with value: 0.20879356992622067 and parameters: {'max_depth': 17, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.502780748073501, 'subsample': 0.21770174390604896, 'n_estimators': 188}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:06,830] Trial 477 finished with value: 0.20440468988166693 and parameters: {'max_depth': 18, 'gamma': 2, 'max_delta_step': 0, 'min_child_weight': 9, 'learning_rate': 0.5840773556310734, 'subsample': 0.27266205435780533, 'n_estimators': 43}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:09,564] Trial 478 finished with value: 0.22650955190956212 and parameters: {'max_depth': 2, 'gamma': 4, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.445493761839447, 'subsample': 0.3274823468782478, 'n_estimators': 233}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:11,172] Trial 479 finished with value: 0.20805170999613287 and parameters: {'max_depth': 17, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 6, 'learning_rate': 0.554782815781285, 'subsample': 0.24357082910324226, 'n_estimators': 224}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:12,810] Trial 480 finished with value: 0.18466971350861416 and parameters: {'max_depth': 19, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 7, 'learning_rate': 0.5220145309953462, 'subsample': 0.29306143827346315, 'n_estimators': 192}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:20,891] Trial 481 finished with value: -0.1941919202502227 and parameters: {'max_depth': 16, 'gamma': 5, 'max_delta_step': 2, 'min_child_weight': 8, 'learning_rate': 0.9994055073870225, 'subsample': 0.263786418570454, 'n_estimators': 211}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:23,371] Trial 482 finished with value: 0.24672284182959947 and parameters: {'max_depth': 17, 'gamma': 6, 'max_delta_step': 11, 'min_child_weight': 7, 'learning_rate': 0.4771087132690608, 'subsample': 0.31185353957635187, 'n_estimators': 199}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:25,284] Trial 483 finished with value: 0.20704956472519942 and parameters: {'max_depth': 18, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.6506141751540642, 'subsample': 0.2334648640430482, 'n_estimators': 55}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:27,223] Trial 484 finished with value: 0.2509066339553335 and parameters: {'max_depth': 1, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.5376036872148137, 'subsample': 0.2865301507962471, 'n_estimators': 169}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:29,237] Trial 485 finished with value: 0.1630839061650191 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 2, 'min_child_weight': 7, 'learning_rate': 0.6016723953298554, 'subsample': 0.36550601484629025, 'n_estimators': 180}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:36,530] Trial 486 finished with value: 0.27655443020638537 and parameters: {'max_depth': 9, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.5754076873313537, 'subsample': 0.2575937806459308, 'n_estimators': 205}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:37,999] Trial 487 finished with value: 0.21936992210763118 and parameters: {'max_depth': 15, 'gamma': 5, 'max_delta_step': 5, 'min_child_weight': 6, 'learning_rate': 0.5071359750154215, 'subsample': 0.1970870087618407, 'n_estimators': 38}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:39,206] Trial 488 finished with value: 0.16194304532918857 and parameters: {'max_depth': 2, 'gamma': 4, 'max_delta_step': 3, 'min_child_weight': 7, 'learning_rate': 0.5592085851954668, 'subsample': 0.24625915187357023, 'n_estimators': 241}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:45,136] Trial 489 finished with value: 0.3122494262156259 and parameters: {'max_depth': 20, 'gamma': 6, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.46968497606368864, 'subsample': 0.279614265108278, 'n_estimators': 226}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:46,873] Trial 490 finished with value: 0.2081743314272263 and parameters: {'max_depth': 19, 'gamma': 5, 'max_delta_step': 0, 'min_child_weight': 8, 'learning_rate': 0.5266760401207273, 'subsample': 0.21602662821066265, 'n_estimators': 214}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:48,550] Trial 491 finished with value: 0.25358007900158863 and parameters: {'max_depth': 17, 'gamma': 4, 'max_delta_step': 2, 'min_child_weight': 9, 'learning_rate': 0.42824157414113423, 'subsample': 0.3058479738079703, 'n_estimators': 234}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:50,366] Trial 492 finished with value: 0.269295173814988 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.6273885944402653, 'subsample': 0.26468270868622407, 'n_estimators': 147}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:54:58,714] Trial 493 finished with value: 0.22881107073510143 and parameters: {'max_depth': 17, 'gamma': 6, 'max_delta_step': 0, 'min_child_weight': 6, 'learning_rate': 0.5945606371309299, 'subsample': 0.23327103093835994, 'n_estimators': 60}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:00,448] Trial 494 finished with value: 0.215825670869371 and parameters: {'max_depth': 18, 'gamma': 4, 'max_delta_step': 0, 'min_child_weight': 19, 'learning_rate': 0.49872872419287356, 'subsample': 0.29032398714333274, 'n_estimators': 219}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:01,616] Trial 495 finished with value: 0.1890968357150784 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 3, 'min_child_weight': 8, 'learning_rate': 0.5395300947436952, 'subsample': 0.3210969782870875, 'n_estimators': 195}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:02,615] Trial 496 finished with value: 0.2350452374755777 and parameters: {'max_depth': 18, 'gamma': 4, 'max_delta_step': 12, 'min_child_weight': 7, 'learning_rate': 0.3533043142324114, 'subsample': 0.24921262946382738, 'n_estimators': 50}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:06,942] Trial 497 finished with value: 0.3466970955345968 and parameters: {'max_depth': 1, 'gamma': 3, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.5685052208550009, 'subsample': 0.2732293282734883, 'n_estimators': 44}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:07,969] Trial 498 finished with value: 0.043641107883880204 and parameters: {'max_depth': 19, 'gamma': 2, 'max_delta_step': 1, 'min_child_weight': 8, 'learning_rate': 0.5688177495236483, 'subsample': 0.22098729350858315, 'n_estimators': 87}. Best is trial 141 with value: 0.4317497433622448.
# [I 2025-02-26 01:55:09,010] Trial 499 finished with value: -0.04485979600758694 and parameters: {'max_depth': 17, 'gamma': 2, 'max_delta_step': 1, 'min_child_weight': 1, 'learning_rate': 0.5532150332951679, 'subsample': 0.2648379319267832, 'n_estimators': 228}. Best is trial 141 with value: 0.4317497433622448.
# {'max_depth': 19,
#  'gamma': 5,
#  'max_delta_step': 1,
#  'min_child_weight': 7,
#  'learning_rate': 0.5951214841506621,
#  'subsample': 0.2834638087754667,
#  'n_estimators': 184}

# %% [markdown]
# {'max_depth': 16,
#  'gamma': 2,
#  'max_delta_step': 4,
#  'min_child_weight': 20,
#  'learning_rate': 0.1673266351389645,
#  'subsample': 0.17794938759715506,
#  'n_estimators': 74}

# %%
# We can now assess the model performance on the training set using cross validation
from sklearn.metrics import mean_squared_error
import sklearn
from sklearn import metrics

print(sklearn.metrics.get_scorer_names())

CrossValAssessor(
    scoring="neg_mean_absolute_error",
    split=BootstrapSplit(split=ClusterSplit(dataset_sars), n_bootstraps=100)
)(model_sars, dataset_sars)

# and on the test set
TestSetAssessor("neg_mean_absolute_error")(model_sars, dataset_sars)

# Finally, we need to fit the model on the complete dataset if we want to use it further
model_sars.fitDataset(dataset_sars)

# and save the model
_ = model_sars.save()
# Out:
# ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'max_error', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_negative_likelihood_ratio', 'neg_root_mean_squared_error', 'neg_root_mean_squared_log_error', 'normalized_mutual_info_score', 'positive_likelihood_ratio', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc', 'roc_auc_ovo', 'roc_auc_ovo_weighted', 'roc_auc_ovr', 'roc_auc_ovr_weighted', 'top_k_accuracy', 'v_measure_score']

# %%
from rdkit import Chem
from rdkit.Chem import MolStandardize

def read_smi_file(file_path):
    smiles_list = []
    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Skip comment lines and empty lines
                if line.strip() and not line.startswith('#'):
                    # SMILES strings are typically separated by whitespace or tab
                    smiles = line.split()[0]
                    smiles_list.append(smiles)
    except FileNotFoundError:
        print("File not found.")
    return smiles_list

# Example usage to read the standardized SMILES file and create a list
file_path = 'test_potency.smi'
smiles_list = read_smi_file(file_path)
print("SMILES in the file:")
print(len(smiles_list))
# Out:
# SMILES in the file:
# 297

# %%
well = model_sars.predictMols(smiles_list_test)

# %%
print(well)
# Out:
# [[5.2606316]
#  [6.042621 ]
#  [5.5060997]
#  [5.7655044]
#  [6.3580527]
#  [6.635112 ]
#  [5.8555408]
#  [6.781377 ]
#  [6.5181847]
#  [6.5181847]
#  [6.125652 ]
#  [7.2176757]
#  [6.455889 ]
#  [7.156018 ]
#  [5.78455  ]
#  [6.902244 ]
#  [6.653148 ]
#  [6.085179 ]
#  [4.744858 ]
#  [6.31968  ]
#  [7.1286716]
#  [7.4047213]
#  [6.65365  ]
#  [8.3577795]
#  [5.84428  ]
#  [6.5421844]
#  [6.1597114]
#  [7.3859096]
#  [5.9935613]
#  [4.979324 ]
#  [6.635112 ]
#  [6.978636 ]
#  [6.6643333]
#  [6.332336 ]
#  [6.65365  ]
#  [6.332336 ]
#  [6.615716 ]
#  [6.313798 ]
#  [6.635112 ]
#  [6.514045 ]
#  [6.332336 ]
#  [6.332336 ]
#  [7.0407805]
#  [7.0407805]
#  [7.5038323]
#  [7.5038323]
#  [5.9526405]
#  [5.9526405]
#  [6.927808 ]
#  [6.927808 ]
#  [6.6376767]
#  [6.635112 ]
#  [6.8372865]
#  [6.65365  ]
#  [5.7378697]
#  [6.5267005]
#  [6.332336 ]
#  [6.313798 ]
#  [6.8294764]
#  [6.509946 ]
#  [6.4625707]
#  [6.550733 ]
#  [6.550733 ]
#  [6.65365  ]
#  [7.6429057]
#  [6.176478 ]
#  [7.365069 ]
#  [7.685716 ]
#  [6.635112 ]
#  [6.987118 ]
#  [6.332336 ]
#  [7.427582 ]
#  [7.427582 ]
#  [6.332336 ]
#  [6.65365  ]
#  [6.2001977]
#  [6.2001977]
#  [7.697893 ]
#  [6.65365  ]
#  [7.1267576]
#  [6.663706 ]
#  [6.663706 ]
#  [7.1467543]
#  [6.332336 ]
#  [6.8254404]
#  [6.8254404]
#  [6.635112 ]
#  [7.704641 ]
#  [6.532812 ]
#  [6.96858  ]
#  [7.427582 ]
#  [8.393517 ]
#  [7.427582 ]
#  [7.726003 ]
#  [6.998111 ]
#  [7.427582 ]
#  [7.427582 ]
#  [7.832023 ]
#  [7.6510844]
#  [7.602226 ]
#  [7.6510844]
#  [7.427582 ]
#  [7.726003 ]
#  [7.6510844]
#  [6.932654 ]
#  [7.0351543]
#  [6.7506523]
#  [6.6343613]
#  [6.832122 ]
#  [5.8715816]
#  [6.6849065]
#  [7.16559  ]
#  [6.237375 ]
#  [7.427582 ]
#  [6.3580527]
#  [7.6510844]
#  [6.3580527]
#  [5.829916 ]
#  [6.3580527]
#  [7.016527 ]
#  [7.016527 ]
#  [7.3779225]
#  [6.8044076]
#  [7.480222 ]
#  [6.3580527]
#  [7.016527 ]
#  [6.8765335]
#  [6.276271 ]
#  [4.473395 ]
#  [6.588196 ]
#  [7.300128 ]
#  [5.158047 ]
#  [5.322756 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.162691 ]
#  [4.294673 ]
#  [4.217253 ]
#  [5.747442 ]
#  [4.538567 ]
#  [5.372561 ]
#  [4.333793 ]
#  [5.5508018]
#  [5.611409 ]
#  [4.294673 ]
#  [4.162691 ]
#  [4.3112264]
#  [4.792427 ]
#  [4.0273795]
#  [5.8715816]
#  [5.9709444]
#  [5.9709444]
#  [4.586063 ]
#  [4.6924105]
#  [4.538567 ]
#  [5.521046 ]
#  [4.0273795]
#  [6.810054 ]
#  [6.810054 ]
#  [4.792427 ]
#  [4.538567 ]
#  [4.537925 ]
#  [5.2005434]
#  [4.919751 ]
#  [5.143254 ]
#  [4.792427 ]
#  [4.3112264]
#  [4.8202977]
#  [4.538567 ]
#  [5.5502677]
#  [5.4219174]
#  [5.6416845]
#  [5.233923 ]
#  [7.1589084]
#  [5.220027 ]
#  [5.366106 ]
#  [6.8254404]
#  [5.4365425]
#  [7.1589084]
#  [5.255806 ]
#  [5.359931 ]
#  [7.2298813]
#  [5.24893  ]
#  [7.9437294]
#  [8.014701 ]
#  [4.991377 ]
#  [5.16299  ]
#  [5.806286 ]
#  [5.7700233]
#  [4.4568024]
#  [5.255806 ]
#  [6.3941813]
#  [6.1122413]
#  [5.9709444]
#  [5.7269297]
#  [5.16299  ]
#  [5.7269297]
#  [4.4695425]
#  [5.915426 ]
#  [5.915426 ]
#  [6.1732845]
#  [4.868197 ]
#  [4.3112264]
#  [4.3312654]
#  [3.9899125]
#  [4.872035 ]
#  [3.9485354]
#  [3.9899125]
#  [5.030351 ]
#  [4.474945 ]
#  [4.2037473]
#  [4.6592183]
#  [4.6592183]
#  [4.4847   ]
#  [4.4847   ]
#  [4.440756 ]
#  [4.440756 ]
#  [5.6416845]
#  [3.6401129]
#  [3.6401129]
#  [4.757581 ]
#  [4.757581 ]
#  [4.872035 ]
#  [3.6469517]
#  [5.085165 ]
#  [5.977626 ]
#  [5.977626 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.6585903]
#  [4.6585903]
#  [4.984922 ]
#  [4.815626 ]
#  [4.7620697]
#  [4.987539 ]
#  [4.987539 ]
#  [4.778116 ]
#  [4.538567 ]
#  [5.1094337]
#  [4.6585903]
#  [4.6585903]
#  [4.766474 ]
#  [4.538567 ]
#  [5.225578 ]
#  [4.658132 ]
#  [5.219399 ]
#  [3.4826329]
#  [4.979303 ]
#  [5.428868 ]
#  [4.163427 ]
#  [4.163427 ]
#  [4.919751 ]
#  [4.815626 ]
#  [5.12548  ]
#  [5.770301 ]
#  [5.6416845]
#  [5.085165 ]
#  [5.330357 ]
#  [3.8525918]
#  [4.7620697]
#  [4.885931 ]
#  [4.538567 ]
#  [5.172976 ]
#  [4.0530515]
#  [4.868197 ]
#  [4.868197 ]
#  [5.002075 ]
#  [4.538567 ]
#  [5.12548  ]
#  [4.5100093]
#  [4.538567 ]
#  [4.564617 ]
#  [4.5677886]
#  [4.8572383]
#  [4.7338614]
#  [4.6592183]
#  [4.6592183]
#  [4.6592183]
#  [4.6592183]
#  [3.6227844]
#  [4.538567 ]
#  [4.418583 ]
#  [4.737916 ]
#  [4.538567 ]
#  [4.7620697]
#  [4.7620697]
#  [4.658132 ]
#  [4.1683936]
#  [4.538567 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.538567 ]
#  [4.7620697]
#  [6.0469418]
#  [6.0469418]]

# %%
min_length = min(len(smiles_list_test), len(well))
values = [val[0] for val in well[:min_length]]

# %%
print(values)
# Out:
# [5.2606316, 6.042621, 5.5060997, 5.7655044, 6.3580527, 6.635112, 5.8555408, 6.781377, 6.5181847, 6.5181847, 6.125652, 7.2176757, 6.455889, 7.156018, 5.78455, 6.902244, 6.653148, 6.085179, 4.744858, 6.31968, 7.1286716, 7.4047213, 6.65365, 8.3577795, 5.84428, 6.5421844, 6.1597114, 7.3859096, 5.9935613, 4.979324, 6.635112, 6.978636, 6.6643333, 6.332336, 6.65365, 6.332336, 6.615716, 6.313798, 6.635112, 6.514045, 6.332336, 6.332336, 7.0407805, 7.0407805, 7.5038323, 7.5038323, 5.9526405, 5.9526405, 6.927808, 6.927808, 6.6376767, 6.635112, 6.8372865, 6.65365, 5.7378697, 6.5267005, 6.332336, 6.313798, 6.8294764, 6.509946, 6.4625707, 6.550733, 6.550733, 6.65365, 7.6429057, 6.176478, 7.365069, 7.685716, 6.635112, 6.987118, 6.332336, 7.427582, 7.427582, 6.332336, 6.65365, 6.2001977, 6.2001977, 7.697893, 6.65365, 7.1267576, 6.663706, 6.663706, 7.1467543, 6.332336, 6.8254404, 6.8254404, 6.635112, 7.704641, 6.532812, 6.96858, 7.427582, 8.393517, 7.427582, 7.726003, 6.998111, 7.427582, 7.427582, 7.832023, 7.6510844, 7.602226, 7.6510844, 7.427582, 7.726003, 7.6510844, 6.932654, 7.0351543, 6.7506523, 6.6343613, 6.832122, 5.8715816, 6.6849065, 7.16559, 6.237375, 7.427582, 6.3580527, 7.6510844, 6.3580527, 5.829916, 6.3580527, 7.016527, 7.016527, 7.3779225, 6.8044076, 7.480222, 6.3580527, 7.016527, 6.8765335, 6.276271, 4.473395, 6.588196, 7.300128, 5.158047, 5.322756, 4.538567, 4.538567, 4.538567, 4.162691, 4.294673, 4.217253, 5.747442, 4.538567, 5.372561, 4.333793, 5.5508018, 5.611409, 4.294673, 4.162691, 4.3112264, 4.792427, 4.0273795, 5.8715816, 5.9709444, 5.9709444, 4.586063, 4.6924105, 4.538567, 5.521046, 4.0273795, 6.810054, 6.810054, 4.792427, 4.538567, 4.537925, 5.2005434, 4.919751, 5.143254, 4.792427, 4.3112264, 4.8202977, 4.538567, 5.5502677, 5.4219174, 5.6416845, 5.233923, 7.1589084, 5.220027, 5.366106, 6.8254404, 5.4365425, 7.1589084, 5.255806, 5.359931, 7.2298813, 5.24893, 7.9437294, 8.014701, 4.991377, 5.16299, 5.806286, 5.7700233, 4.4568024, 5.255806, 6.3941813, 6.1122413, 5.9709444, 5.7269297, 5.16299, 5.7269297, 4.4695425, 5.915426, 5.915426, 6.1732845, 4.868197, 4.3112264, 4.3312654, 3.9899125, 4.872035, 3.9485354, 3.9899125, 5.030351, 4.474945, 4.2037473, 4.6592183, 4.6592183, 4.4847, 4.4847, 4.440756, 4.440756, 5.6416845, 3.6401129, 3.6401129, 4.757581, 4.757581, 4.872035, 3.6469517, 5.085165, 5.977626, 5.977626, 4.538567, 4.538567, 4.538567, 4.6585903, 4.6585903, 4.984922, 4.815626, 4.7620697, 4.987539, 4.987539, 4.778116, 4.538567, 5.1094337, 4.6585903, 4.6585903, 4.766474, 4.538567, 5.225578, 4.658132, 5.219399, 3.4826329, 4.979303, 5.428868, 4.163427, 4.163427, 4.919751, 4.815626, 5.12548, 5.770301, 5.6416845, 5.085165, 5.330357, 3.8525918, 4.7620697, 4.885931, 4.538567, 5.172976, 4.0530515, 4.868197, 4.868197, 5.002075, 4.538567, 5.12548, 4.5100093, 4.538567, 4.564617, 4.5677886, 4.8572383, 4.7338614, 4.6592183, 4.6592183, 4.6592183, 4.6592183, 3.6227844, 4.538567, 4.418583, 4.737916, 4.538567, 4.7620697, 4.7620697, 4.658132, 4.1683936, 4.538567, 4.538567, 4.538567, 4.538567, 4.7620697, 6.0469418, 6.0469418]

# %%
# Write to CSV file
with open("sars_prediction_preliminary.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["SMILES", "SARS"])
    for smiles, value in zip(smiles_list_test, values):
        writer.writerow([smiles, value])

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %% [markdown]
# The End.
