# %% [markdown]
# # Ligand ADMET and Potency (Property Prediction)
#
# The [ADMET](https://polarishub.io/competitions/asap-discovery/antiviral-admet-2025) and [Potency](https://polarishub.io/competitions/asap-discovery/antiviral-potency-2025) Challenge of the [ASAP Discovery competition](https://polarishub.io/blog/antiviral-competition) take the shape of a property prediction task. Given the SMILES (or, to be more precise, the CXSMILES) of a molecule, you are asked to predict the numerical properties of said molecule. This is a relatively straight-forward application of ML and this notebook will quickly get you up and running!
#
# To begin with, choose one of the two challenges! The code will look the same for both.

# %% [markdown]
# As suggested in the logs, we'll cache the dataset. Note that this is not strictly necessary, but it does speed up later steps.

# %%
import pandas as pd

potency_df = pd.read_csv("antiviral_potency_2025.csv")

# %%
potency_df
# Out:
#                                                CXSMILES Molecule Name    Set  \
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...  ASAP-0000141  Train
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000142  Train
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...  ASAP-0000143  Train
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000144  Train
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000145  Train
# ...                                                 ...           ...    ...
# 1323  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032561   Test
# 1324  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032562   Test
# 1325  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...  ASAP-0032572   Test
# 1326  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032604   Test
# 1327  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032605   Test
#
#       pIC50 (MERS-CoV Mpro)  pIC50 (SARS-CoV-2 Mpro)
# 0                      4.19                      NaN
# 1                      4.92                     5.29
# 2                      4.73                      NaN
# 3                      4.90                     6.11
# 4                      4.81                     5.62
# ...                     ...                      ...
# 1323                   4.54                     4.20
# 1324                   4.42                      NaN
# 1325                   4.84                     5.18
# 1326                   5.53                     5.59
# 1327                   5.47                     5.77
#
# [1328 rows x 5 columns]

# %%
train_df = potency_df[potency_df['Set'] == 'Train'].rename(columns={'CXSMILES': 'SMILES'})

# %%
test_mers_df = (
    potency_df[
        (potency_df['Set'] == 'Test') &
        (potency_df['pIC50 (MERS-CoV Mpro)'].notna())
    ]
    .rename(columns={'CXSMILES': 'SMILES'})
)

# %%
test_mers_df
# Out:
#                                                  SMILES Molecule Name   Set  \
# 1031  C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...  ASAP-0000175  Test
# 1032  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000272  Test
# 1033  CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...  ASAP-0000528  Test
# 1034  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000541  Test
# 1035  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000733  Test
# ...                                                 ...           ...   ...
# 1323  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032561  Test
# 1324  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032562  Test
# 1325  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...  ASAP-0032572  Test
# 1326  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032604  Test
# 1327  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032605  Test
#
#       pIC50 (MERS-CoV Mpro)  pIC50 (SARS-CoV-2 Mpro)
# 1031                   5.52                     5.57
# 1032                   6.47                      NaN
# 1033                   5.80                     7.44
# 1034                   5.81                     6.48
# 1035                   6.69                     7.87
# ...                     ...                      ...
# 1323                   4.54                     4.20
# 1324                   4.42                      NaN
# 1325                   4.84                     5.18
# 1326                   5.53                     5.59
# 1327                   5.47                     5.77
#
# [297 rows x 5 columns]

# %%
test_sars_df = (
    potency_df[
        (potency_df['Set'] == 'Test') &
        (potency_df['pIC50 (SARS-CoV-2 Mpro)'].notna())
    ]
    .rename(columns={'CXSMILES': 'SMILES'})
)

# %%
test_sars_df
# Out:
#                                                  SMILES Molecule Name   Set  \
# 1031  C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...  ASAP-0000175  Test
# 1033  CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...  ASAP-0000528  Test
# 1034  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000541  Test
# 1035  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000733  Test
# 1036  CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[...  ASAP-0000738  Test
# ...                                                 ...           ...   ...
# 1322  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032560  Test
# 1323  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032561  Test
# 1325  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...  ASAP-0032572  Test
# 1326  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032604  Test
# 1327  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032605  Test
#
#       pIC50 (MERS-CoV Mpro)  pIC50 (SARS-CoV-2 Mpro)
# 1031                   5.52                     5.57
# 1033                   5.80                     7.44
# 1034                   5.81                     6.48
# 1035                   6.69                     7.87
# 1036                   5.98                     7.60
# ...                     ...                      ...
# 1322                   4.33                     4.02
# 1323                   4.54                     4.20
# 1325                   4.84                     5.18
# 1326                   5.53                     5.59
# 1327                   5.47                     5.77
#
# [263 rows x 5 columns]

# %%
train_df.to_csv("potency_training_unblinded.csv")

# %% [markdown]
# ### Raw data dump
# We've decided to sacrifice the completeness of the scientific data to improve its ease of use. For those that are interested, you can also access the raw data dump that this dataset has been created from.

# %% [markdown]
# ## Build a model
# Next, we'll train a simple baseline model using scikit-learn.
#
# You'll notice that the challenge has multiple targets.

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

# %%
mers_props = [
    {"name": "pIC50 (MERS-CoV Mpro)", "task": "REGRESSION"},]

# %% [markdown]
# ## MERS Model Generation

# %% [markdown]
# Create for PCA QSPRDataset of test and training with known Descriptors, which were previously calculated

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

dataset_test_mers = QSPRDataset(
    name="MultiTaskTutorialDataset",
    target_props=mers_props,
    df=test_mers_df,
    store_dir="mers_output_adjusted_22/data_test2",
    overwrite=True
)


dataset_test_mers.getDF()
# Out:
#                                                                          SMILES  \
# QSPRID
# MultiTaskTutorialDataset_000  C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...
# MultiTaskTutorialDataset_001  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# MultiTaskTutorialDataset_002  CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...
# MultiTaskTutorialDataset_003  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# MultiTaskTutorialDataset_004  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# ...                                                                         ...
# MultiTaskTutorialDataset_292  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# MultiTaskTutorialDataset_293  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# MultiTaskTutorialDataset_294  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...
# MultiTaskTutorialDataset_295  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
# MultiTaskTutorialDataset_296  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
#
#                              Molecule Name   Set  pIC50 (MERS-CoV Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000  ASAP-0000175  Test                   5.52
# MultiTaskTutorialDataset_001  ASAP-0000272  Test                   6.47
# MultiTaskTutorialDataset_002  ASAP-0000528  Test                   5.80
# MultiTaskTutorialDataset_003  ASAP-0000541  Test                   5.81
# MultiTaskTutorialDataset_004  ASAP-0000733  Test                   6.69
# ...                                    ...   ...                    ...
# MultiTaskTutorialDataset_292  ASAP-0032561  Test                   4.54
# MultiTaskTutorialDataset_293  ASAP-0032562  Test                   4.42
# MultiTaskTutorialDataset_294  ASAP-0032572  Test                   4.84
# MultiTaskTutorialDataset_295  ASAP-0032604  Test                   5.53
# MultiTaskTutorialDataset_296  ASAP-0032605  Test                   5.47
#
#                               pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000                     5.57
# MultiTaskTutorialDataset_001                      NaN
# MultiTaskTutorialDataset_002                     7.44
# MultiTaskTutorialDataset_003                     6.48
# MultiTaskTutorialDataset_004                     7.87
# ...                                               ...
# MultiTaskTutorialDataset_292                     4.20
# MultiTaskTutorialDataset_293                      NaN
# MultiTaskTutorialDataset_294                     5.18
# MultiTaskTutorialDataset_295                     5.59
# MultiTaskTutorialDataset_296                     5.77
#
#                                                     QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_000  MultiTaskTutorialDataset_000
# MultiTaskTutorialDataset_001  MultiTaskTutorialDataset_001
# MultiTaskTutorialDataset_002  MultiTaskTutorialDataset_002
# MultiTaskTutorialDataset_003  MultiTaskTutorialDataset_003
# MultiTaskTutorialDataset_004  MultiTaskTutorialDataset_004
# ...                                                    ...
# MultiTaskTutorialDataset_292  MultiTaskTutorialDataset_292
# MultiTaskTutorialDataset_293  MultiTaskTutorialDataset_293
# MultiTaskTutorialDataset_294  MultiTaskTutorialDataset_294
# MultiTaskTutorialDataset_295  MultiTaskTutorialDataset_295
# MultiTaskTutorialDataset_296  MultiTaskTutorialDataset_296
#
#                               pIC50 (MERS-CoV Mpro)_original
# QSPRID
# MultiTaskTutorialDataset_000                            5.52
# MultiTaskTutorialDataset_001                            6.47
# MultiTaskTutorialDataset_002                            5.80
# MultiTaskTutorialDataset_003                            5.81
# MultiTaskTutorialDataset_004                            6.69
# ...                                                      ...
# MultiTaskTutorialDataset_292                            4.54
# MultiTaskTutorialDataset_293                            4.42
# MultiTaskTutorialDataset_294                            4.84
# MultiTaskTutorialDataset_295                            5.53
# MultiTaskTutorialDataset_296                            5.47
#
# [297 rows x 7 columns]

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_test_mers)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_test_mers.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=4, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_test_mers.y)}")
print(f"Number of samples test set: {len(dataset_test_mers.y_ind)}")

print(type(dataset_test_mers.X))
print(dataset_test_mers.X.shape)
print(dataset_test_mers.X_ind.shape)


dataset_test_mers.save()
# Out:
# Number of samples train set: 237
# Number of samples test set: 60
# <class 'pandas.core.frame.DataFrame'>
# (237, 1280)
# (60, 1280)

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

dataset_mers = QSPRDataset(
    name="MultiTaskTutorialDataset",
    target_props=mers_props,
    df=train_df,
    store_dir="mers_output_adjusted_22/data2",
    overwrite=True
)


dataset_mers.getDF()
# Out:
#                                                                           SMILES  \
# QSPRID
# MultiTaskTutorialDataset_0000  COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...
# MultiTaskTutorialDataset_0001  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# MultiTaskTutorialDataset_0002  CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...
# MultiTaskTutorialDataset_0003  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# MultiTaskTutorialDataset_0004  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# ...                                                                          ...
# MultiTaskTutorialDataset_1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...
# MultiTaskTutorialDataset_1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...
# MultiTaskTutorialDataset_1028  CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
# MultiTaskTutorialDataset_1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...
# MultiTaskTutorialDataset_1030  O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...
#
#                               Molecule Name    Set  pIC50 (MERS-CoV Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_0000  ASAP-0000141  Train                   4.19
# MultiTaskTutorialDataset_0001  ASAP-0000142  Train                   4.92
# MultiTaskTutorialDataset_0002  ASAP-0000143  Train                   4.73
# MultiTaskTutorialDataset_0003  ASAP-0000144  Train                   4.90
# MultiTaskTutorialDataset_0004  ASAP-0000145  Train                   4.81
# ...                                     ...    ...                    ...
# MultiTaskTutorialDataset_1026  ASAP-0031916  Train                   5.57
# MultiTaskTutorialDataset_1027  ASAP-0031917  Train                   4.60
# MultiTaskTutorialDataset_1028  ASAP-0031918  Train                   4.22
# MultiTaskTutorialDataset_1029  ASAP-0031920  Train                   4.40
# MultiTaskTutorialDataset_1030  ASAP-0031932  Train                   4.22
#
#                                pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_0000                      NaN
# MultiTaskTutorialDataset_0001                     5.29
# MultiTaskTutorialDataset_0002                      NaN
# MultiTaskTutorialDataset_0003                     6.11
# MultiTaskTutorialDataset_0004                     5.62
# ...                                                ...
# MultiTaskTutorialDataset_1026                     6.38
# MultiTaskTutorialDataset_1027                     6.09
# MultiTaskTutorialDataset_1028                      NaN
# MultiTaskTutorialDataset_1029                     5.06
# MultiTaskTutorialDataset_1030                      NaN
#
#                                                       QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_0000  MultiTaskTutorialDataset_0000
# MultiTaskTutorialDataset_0001  MultiTaskTutorialDataset_0001
# MultiTaskTutorialDataset_0002  MultiTaskTutorialDataset_0002
# MultiTaskTutorialDataset_0003  MultiTaskTutorialDataset_0003
# MultiTaskTutorialDataset_0004  MultiTaskTutorialDataset_0004
# ...                                                      ...
# MultiTaskTutorialDataset_1026  MultiTaskTutorialDataset_1026
# MultiTaskTutorialDataset_1027  MultiTaskTutorialDataset_1027
# MultiTaskTutorialDataset_1028  MultiTaskTutorialDataset_1028
# MultiTaskTutorialDataset_1029  MultiTaskTutorialDataset_1029
# MultiTaskTutorialDataset_1030  MultiTaskTutorialDataset_1030
#
#                                pIC50 (MERS-CoV Mpro)_original
# QSPRID
# MultiTaskTutorialDataset_0000                            4.19
# MultiTaskTutorialDataset_0001                            4.92
# MultiTaskTutorialDataset_0002                            4.73
# MultiTaskTutorialDataset_0003                            4.90
# MultiTaskTutorialDataset_0004                            4.81
# ...                                                       ...
# MultiTaskTutorialDataset_1026                            5.57
# MultiTaskTutorialDataset_1027                            4.60
# MultiTaskTutorialDataset_1028                            4.22
# MultiTaskTutorialDataset_1029                            4.40
# MultiTaskTutorialDataset_1030                            4.22
#
# [901 rows x 7 columns]

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_mers)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_mers.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=4, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_mers.y)}")
print(f"Number of samples test set: {len(dataset_mers.y_ind)}")

print(type(dataset_mers.X))
print(dataset_mers.X.shape)
print(dataset_mers.X_ind.shape)


dataset_mers.save()
# Out:
# Number of samples train set: 721
# Number of samples test set: 180
# <class 'pandas.core.frame.DataFrame'>
# (721, 1280)
# (180, 1280)

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_mers)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_mers.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=4, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_mers.y)}")
print(f"Number of samples test set: {len(dataset_mers.y_ind)}")

print(type(dataset_mers.X))
print(dataset_mers.X.shape)
print(dataset_mers.X_ind.shape)


dataset_mers.save()
# Out:
# Number of samples train set: 721
# Number of samples test set: 180
# <class 'pandas.core.frame.DataFrame'>
# (721, 1280)
# (180, 1280)

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Combine train and test for X into one "Train"
X_all_train = np.vstack([dataset_mers.X, dataset_mers.X_ind])

# Combine train and test for Y into one "Test"
X_all_test = np.vstack([dataset_test_mers.X, dataset_test_mers.X_ind])

# Fit PCA on combined space so both sets are projected in same PC space
X_combined = np.vstack([X_all_train, X_all_test])
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_combined)

# Separate transformed "train" and "test"
X_train_pca = X_pca[:len(X_all_train)]
X_test_pca = X_pca[len(X_all_train):]

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], 
            alpha=0.6, label='Train', c='blue')
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], 
            alpha=0.6, label='Test', c='red')

plt.xlabel(f"PC1")
plt.ylabel(f"PC2")
plt.title("PCA of Molecular Fingerprints for MERS-CoV MPro")
plt.legend()

plt.savefig("PCA_train_test_mers_256.png", dpi=300)
plt.show()

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_mers)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_mers.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=4, nBits=256)],
    recalculate_features=True,
    feature_filters=[LowVarianceFilter(0.001)],
    feature_standardizer=StandardScaler()
)

print(f"Number of samples train set: {len(dataset_mers.y)}")
print(f"Number of samples test set: {len(dataset_mers.y_ind)}")

print(type(dataset_mers.X))
print(dataset_mers.X.shape)
print(dataset_mers.X_ind.shape)


dataset_mers.save()
# Out:
# Number of samples train set: 721
# Number of samples test set: 180
# <class 'pandas.core.frame.DataFrame'>
# (721, 1249)
# (180, 1249)

# %%
from qsprpred.models import SklearnModel
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor
from qsprpred.models import CrossValAssessor, TestSetAssessor

os.makedirs("class_models/XG_models_clust_mers_test2", exist_ok=True)

# This is an SKlearn model, so we will initialize it with the SklearnModel class
model_mers = SklearnModel(
    base_dir="class_models/XG_models_clust_mers_test2",
    alg=XGBRegressor,
    name="XGMorgan_clustsplit"
)

import numpy as np
from qsprpred.models import GridSearchOptimization, CrossValAssessor

# %%
from qsprpred.models import OptunaOptimization, TestSetAssessor
from sklearn.model_selection import KFold

# Note the specification of the hyperparameter types as first item in the list
search_space = {"max_depth": ["int", 1, 20],
                "gamma": ["int", 0, 20],
                "max_delta_step": ["int", 0, 20],
                "min_child_weight": ["int", 1, 20],
                "learning_rate": ["float", 0.001, 1],
                "subsample": ["float", 0.001, 1],
                "n_estimators": ["int", 10, 250],
               }

# Optuna gridsearcher with the TestSetAssessor
gridsearcher = OptunaOptimization(
    n_trials=2500,
    param_grid=search_space,
    model_assessor=TestSetAssessor(scoring='neg_mean_absolute_error'),
)
gridsearcher.optimize(model_mers, dataset_mers)
# Out:
# [I 2025-08-12 22:59:50,450] A new study created in memory with name: no-name-489891d0-c9f3-4aa5-895c-8d702d0d8bb6
# [I 2025-08-12 22:59:50,632] Trial 0 finished with value: -0.5742501046922471 and parameters: {'max_depth': 3, 'gamma': 19, 'max_delta_step': 3, 'min_child_weight': 6, 'learning_rate': 0.8695004742874567, 'subsample': 0.4351757402463968, 'n_estimators': 128}. Best is trial 0 with value: -0.5742501046922471.
# [I 2025-08-12 22:59:50,676] Trial 1 finished with value: -0.5649429684744941 and parameters: {'max_depth': 20, 'gamma': 11, 'max_delta_step': 16, 'min_child_weight': 5, 'learning_rate': 0.015197394308445078, 'subsample': 0.18815703749713103, 'n_estimators': 123}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:50,718] Trial 2 finished with value: -0.6042850379943848 and parameters: {'max_depth': 16, 'gamma': 17, 'max_delta_step': 0, 'min_child_weight': 1, 'learning_rate': 0.14505843649811603, 'subsample': 0.04346804670617578, 'n_estimators': 90}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:50,877] Trial 3 finished with value: -0.9975619877179464 and parameters: {'max_depth': 11, 'gamma': 0, 'max_delta_step': 13, 'min_child_weight': 14, 'learning_rate': 0.6495379476012741, 'subsample': 0.5327946648188341, 'n_estimators': 162}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:50,934] Trial 4 finished with value: -0.5706117392645942 and parameters: {'max_depth': 5, 'gamma': 4, 'max_delta_step': 12, 'min_child_weight': 2, 'learning_rate': 0.24787882955401846, 'subsample': 0.9436734180694669, 'n_estimators': 223}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:50,993] Trial 5 finished with value: -0.8852350408766004 and parameters: {'max_depth': 9, 'gamma': 4, 'max_delta_step': 12, 'min_child_weight': 1, 'learning_rate': 0.9260211503715827, 'subsample': 0.5682162239952483, 'n_estimators': 145}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:51,036] Trial 6 finished with value: -0.5749187393188476 and parameters: {'max_depth': 8, 'gamma': 15, 'max_delta_step': 3, 'min_child_weight': 19, 'learning_rate': 0.6957676538063242, 'subsample': 0.9469936921733858, 'n_estimators': 160}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:51,107] Trial 7 finished with value: -0.8989392719268798 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 1, 'min_child_weight': 7, 'learning_rate': 0.7591985322892435, 'subsample': 0.3776608510873027, 'n_estimators': 142}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:51,159] Trial 8 finished with value: -0.5964025600221422 and parameters: {'max_depth': 14, 'gamma': 17, 'max_delta_step': 3, 'min_child_weight': 13, 'learning_rate': 0.8040971261946552, 'subsample': 0.1351855524774314, 'n_estimators': 197}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:51,199] Trial 9 finished with value: -0.7364620049264696 and parameters: {'max_depth': 17, 'gamma': 1, 'max_delta_step': 5, 'min_child_weight': 17, 'learning_rate': 0.7749434184224323, 'subsample': 0.9475709348098535, 'n_estimators': 89}. Best is trial 1 with value: -0.5649429684744941.
# [I 2025-08-12 22:59:51,227] Trial 10 finished with value: -0.5610965461730958 and parameters: {'max_depth': 19, 'gamma': 10, 'max_delta_step': 20, 'min_child_weight': 8, 'learning_rate': 0.32915096700779395, 'subsample': 0.24245178669415537, 'n_estimators': 14}. Best is trial 10 with value: -0.5610965461730958.
# [I 2025-08-12 22:59:51,254] Trial 11 finished with value: -0.5801430755191379 and parameters: {'max_depth': 20, 'gamma': 10, 'max_delta_step': 20, 'min_child_weight': 8, 'learning_rate': 0.3642445390582028, 'subsample': 0.23251456605966003, 'n_estimators': 11}. Best is trial 10 with value: -0.5610965461730958.
# [I 2025-08-12 22:59:51,281] Trial 12 finished with value: -0.5790958976745605 and parameters: {'max_depth': 20, 'gamma': 10, 'max_delta_step': 20, 'min_child_weight': 11, 'learning_rate': 0.019606674528108475, 'subsample': 0.25626104346879564, 'n_estimators': 10}. Best is trial 10 with value: -0.5610965461730958.
# [I 2025-08-12 22:59:51,324] Trial 13 finished with value: -0.5707395024829441 and parameters: {'max_depth': 20, 'gamma': 13, 'max_delta_step': 16, 'min_child_weight': 5, 'learning_rate': 0.47073281827541, 'subsample': 0.709336730114474, 'n_estimators': 66}. Best is trial 10 with value: -0.5610965461730958.
# [I 2025-08-12 22:59:51,385] Trial 14 finished with value: -0.5369416552649604 and parameters: {'max_depth': 13, 'gamma': 7, 'max_delta_step': 17, 'min_child_weight': 9, 'learning_rate': 0.024881406699844344, 'subsample': 0.2905625487738559, 'n_estimators': 55}. Best is trial 14 with value: -0.5369416552649604.
# [I 2025-08-12 22:59:51,438] Trial 15 finished with value: -0.5427074267069498 and parameters: {'max_depth': 12, 'gamma': 7, 'max_delta_step': 16, 'min_child_weight': 10, 'learning_rate': 0.2614095114173821, 'subsample': 0.30544816584880413, 'n_estimators': 46}. Best is trial 14 with value: -0.5369416552649604.
# [I 2025-08-12 22:59:51,480] Trial 16 finished with value: -0.5332613435321384 and parameters: {'max_depth': 12, 'gamma': 7, 'max_delta_step': 8, 'min_child_weight': 11, 'learning_rate': 0.1666790696823809, 'subsample': 0.37980599746242105, 'n_estimators': 51}. Best is trial 16 with value: -0.5332613435321384.
# [I 2025-08-12 22:59:51,516] Trial 17 finished with value: -0.5599809531105889 and parameters: {'max_depth': 13, 'gamma': 7, 'max_delta_step': 7, 'min_child_weight': 14, 'learning_rate': 0.15129885447471297, 'subsample': 0.677052692949653, 'n_estimators': 50}. Best is trial 16 with value: -0.5332613435321384.
# [I 2025-08-12 22:59:51,571] Trial 18 finished with value: -1.0477403120994568 and parameters: {'max_depth': 7, 'gamma': 7, 'max_delta_step': 9, 'min_child_weight': 11, 'learning_rate': 0.5326152372641115, 'subsample': 0.03774845193081505, 'n_estimators': 95}. Best is trial 16 with value: -0.5332613435321384.
# [I 2025-08-12 22:59:51,615] Trial 19 finished with value: -0.531042273097568 and parameters: {'max_depth': 10, 'gamma': 6, 'max_delta_step': 8, 'min_child_weight': 16, 'learning_rate': 0.11772051254928595, 'subsample': 0.3688165417402395, 'n_estimators': 42}. Best is trial 19 with value: -0.531042273097568.
# [I 2025-08-12 22:59:51,654] Trial 20 finished with value: -0.5315821939044528 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 9, 'min_child_weight': 16, 'learning_rate': 0.12827342231702377, 'subsample': 0.6425402304143888, 'n_estimators': 40}. Best is trial 19 with value: -0.531042273097568.
# [I 2025-08-12 22:59:51,698] Trial 21 finished with value: -0.5135423491795857 and parameters: {'max_depth': 2, 'gamma': 5, 'max_delta_step': 9, 'min_child_weight': 17, 'learning_rate': 0.1495730940552064, 'subsample': 0.6222987147123298, 'n_estimators': 30}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,734] Trial 22 finished with value: -0.5287785820431179 and parameters: {'max_depth': 1, 'gamma': 5, 'max_delta_step': 6, 'min_child_weight': 17, 'learning_rate': 0.12320900917193484, 'subsample': 0.7800353272987083, 'n_estimators': 27}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,774] Trial 23 finished with value: -0.595596958902147 and parameters: {'max_depth': 2, 'gamma': 3, 'max_delta_step': 6, 'min_child_weight': 20, 'learning_rate': 0.41638567784159397, 'subsample': 0.8176331540529085, 'n_estimators': 30}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,818] Trial 24 finished with value: -0.5947928887473212 and parameters: {'max_depth': 4, 'gamma': 2, 'max_delta_step': 11, 'min_child_weight': 16, 'learning_rate': 0.2653255492945989, 'subsample': 0.7933448056626277, 'n_estimators': 75}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,852] Trial 25 finished with value: -0.5448671634462144 and parameters: {'max_depth': 5, 'gamma': 5, 'max_delta_step': 5, 'min_child_weight': 17, 'learning_rate': 0.10404251761127913, 'subsample': 0.81757234377489, 'n_estimators': 32}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,895] Trial 26 finished with value: -0.5406601690716214 and parameters: {'max_depth': 1, 'gamma': 9, 'max_delta_step': 10, 'min_child_weight': 19, 'learning_rate': 0.21237639742903125, 'subsample': 0.4789073134725101, 'n_estimators': 108}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,939] Trial 27 finished with value: -0.5374454321331448 and parameters: {'max_depth': 6, 'gamma': 5, 'max_delta_step': 7, 'min_child_weight': 18, 'learning_rate': 0.08051088733693777, 'subsample': 0.6249598211252819, 'n_estimators': 71}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:51,972] Trial 28 finished with value: -0.686641934076945 and parameters: {'max_depth': 3, 'gamma': 0, 'max_delta_step': 5, 'min_child_weight': 15, 'learning_rate': 0.5474591778809006, 'subsample': 0.7670429865298634, 'n_estimators': 26}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,039] Trial 29 finished with value: -0.5613722953796387 and parameters: {'max_depth': 3, 'gamma': 12, 'max_delta_step': 3, 'min_child_weight': 13, 'learning_rate': 0.32729613844875605, 'subsample': 0.583657937041639, 'n_estimators': 250}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,084] Trial 30 finished with value: -0.5312006554073758 and parameters: {'max_depth': 9, 'gamma': 8, 'max_delta_step': 14, 'min_child_weight': 20, 'learning_rate': 0.21662469906340032, 'subsample': 0.45687348336576805, 'n_estimators': 65}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,132] Trial 31 finished with value: -0.5189259501563177 and parameters: {'max_depth': 10, 'gamma': 8, 'max_delta_step': 14, 'min_child_weight': 19, 'learning_rate': 0.20356608226501902, 'subsample': 0.4379277417277416, 'n_estimators': 63}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,168] Trial 32 finished with value: -0.5385176520877415 and parameters: {'max_depth': 10, 'gamma': 6, 'max_delta_step': 9, 'min_child_weight': 18, 'learning_rate': 0.07680414818964314, 'subsample': 0.3626627765324038, 'n_estimators': 29}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,234] Trial 33 finished with value: -0.5559259228176541 and parameters: {'max_depth': 7, 'gamma': 20, 'max_delta_step': 11, 'min_child_weight': 16, 'learning_rate': 0.1861589968592351, 'subsample': 0.8750210313842988, 'n_estimators': 83}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,289] Trial 34 finished with value: -0.563884725994534 and parameters: {'max_depth': 1, 'gamma': 9, 'max_delta_step': 7, 'min_child_weight': 18, 'learning_rate': 0.0052496482714986525, 'subsample': 0.43014079315309894, 'n_estimators': 100}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,345] Trial 35 finished with value: -0.6187218850453695 and parameters: {'max_depth': 4, 'gamma': 3, 'max_delta_step': 14, 'min_child_weight': 15, 'learning_rate': 0.30533938947089345, 'subsample': 0.5358422053084785, 'n_estimators': 121}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,388] Trial 36 finished with value: -0.5474792980617947 and parameters: {'max_depth': 10, 'gamma': 5, 'max_delta_step': 14, 'min_child_weight': 19, 'learning_rate': 0.06345707637215607, 'subsample': 0.7190946010009353, 'n_estimators': 57}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,420] Trial 37 finished with value: -0.5317460925843981 and parameters: {'max_depth': 8, 'gamma': 12, 'max_delta_step': 11, 'min_child_weight': 13, 'learning_rate': 0.3878059287263796, 'subsample': 0.505630184219837, 'n_estimators': 40}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,465] Trial 38 finished with value: -0.5228645558887058 and parameters: {'max_depth': 2, 'gamma': 2, 'max_delta_step': 18, 'min_child_weight': 17, 'learning_rate': 0.11941267750708884, 'subsample': 0.11703901247955412, 'n_estimators': 20}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,503] Trial 39 finished with value: -0.5571278051800198 and parameters: {'max_depth': 2, 'gamma': 1, 'max_delta_step': 17, 'min_child_weight': 20, 'learning_rate': 0.238383438828791, 'subsample': 0.11965087255261102, 'n_estimators': 20}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,533] Trial 40 finished with value: -0.8351679397688971 and parameters: {'max_depth': 5, 'gamma': 4, 'max_delta_step': 13, 'min_child_weight': 17, 'learning_rate': 0.9992195985461383, 'subsample': 0.8819213063610531, 'n_estimators': 22}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,588] Trial 41 finished with value: -0.5351188779407077 and parameters: {'max_depth': 2, 'gamma': 2, 'max_delta_step': 8, 'min_child_weight': 15, 'learning_rate': 0.12638780921076187, 'subsample': 0.09771957456801816, 'n_estimators': 38}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52,672] Trial 42 finished with value: -0.5565103161070083 and parameters: {'max_depth': 4, 'gamma': 6, 'max_delta_step': 19, 'min_child_weight': 17, 'learning_rate': 0.1698794684120493, 'subsample': 0.5839427124445531, 'n_estimators': 191}. Best is trial 21 with value: -0.5135423491795857.
# [I 2025-08-12 22:59:52
and parameters: {'max_depth': 17, 'gamma': 3, 'max_delta_step': 20, 'min_child_weight': 17, 'learning_rate': 0.07870932713861373, 'subsample': 0.28335243897809237, 'n_estimators': 22}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:57,898] Trial 145 finished with value: -0.5411158348719279 and parameters: {'max_depth': 15, 'gamma': 4, 'max_delta_step': 20, 'min_child_weight': 16, 'learning_rate': 0.11430588010303237, 'subsample': 0.25687983282735277, 'n_estimators': 34}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:57,955] Trial 146 finished with value: -0.5102774101893107 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 19, 'min_child_weight': 17, 'learning_rate': 0.060323447057845314, 'subsample': 0.19458970697824945, 'n_estimators': 44}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:57,995] Trial 147 finished with value: -0.5259855109320747 and parameters: {'max_depth': 18, 'gamma': 4, 'max_delta_step': 20, 'min_child_weight': 16, 'learning_rate': 0.09254840509813354, 'subsample': 0.27485035814183, 'n_estimators': 28}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:58,034] Trial 148 finished with value: -0.5538677758110893 and parameters: {'max_depth': 16, 'gamma': 3, 'max_delta_step': 18, 'min_child_weight': 15, 'learning_rate': 0.02344448072288942, 'subsample': 0.30394958810042816, 'n_estimators': 18}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:58,080] Trial 149 finished with value: -0.523243068906996 and parameters: {'max_depth': 15, 'gamma': 3, 'max_delta_step': 19, 'min_child_weight': 18, 'learning_rate': 0.04632054606037009, 'subsample': 0.36106077225680766, 'n_estimators': 23}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:58,118] Trial 150 finished with value: -0.5292497067981295 and parameters: {'max_depth': 15, 'gamma': 5, 'max_delta_step': 17, 'min_child_weight': 18, 'learning_rate': 0.07647965236390139, 'subsample': 0.2382968986748218, 'n_estimators': 32}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:58,169] Trial 151 finished with value: -0.4991862954033746 and parameters: {'max_depth': 16, 'gamma': 2, 'max_delta_step': 20, 'min_child_weight': 10, 'learning_rate': 0.11031335818388277, 'subsample': 0.3321811717645018, 'n_estimators': 15}. Best is trial 116 with value: -0.47425366285112175.
# [I 2025-08-12 22:59:58,235] Trial 152 finished with value: -0.5231083200242785 and parameters: {'max_depth': 17, 'gamma': 2, 'max_delta_step': 20, 'min_child_weight': 10, 'learning_rate': 0.11160879797856393, 'subsample': 0.3314421630276515, 'n_estimators': 40}. Best is trial 116 with value: -0.47425366285112175.
# ...
# [I 2025-08-12 23:03:05,582] Trial 2450 finished with value: -0.5406241944101122 and parameters: {'max_depth': 14, 'gamma': 1, 'max_delta_step': 8, 'min_child_weight': 20, 'learning_rate': 0.16334161067533393, 'subsample': 0.2952561152799786, 'n_estimators': 42}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:05,679] Trial 2451 finished with value: -0.5189202623897129 and parameters: {'max_depth': 15, 'gamma': 0, 'max_delta_step': 9, 'min_child_weight': 7, 'learning_rate': 0.23575129100295047, 'subsample': 0.31186515597476283, 'n_estimators': 18}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:05,770] Trial 2452 finished with value: -0.5123878359264797 and parameters: {'max_depth': 14, 'gamma': 0, 'max_delta_step': 7, 'min_child_weight': 16, 'learning_rate': 0.0671629884742809, 'subsample': 0.3380581750829153, 'n_estimators': 14}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:05,868] Trial 2453 finished with value: -0.483865091641744 and parameters: {'max_depth': 10, 'gamma': 0, 'max_delta_step': 10, 'min_child_weight': 19, 'learning_rate': 0.1289521262231559, 'subsample': 0.28039026704994485, 'n_estimators': 24}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:05,962] Trial 2454 finished with value: -0.55685045337677 and parameters: {'max_depth': 13, 'gamma': 1, 'max_delta_step': 8, 'min_child_weight': 20, 'learning_rate': 0.1806959265191965, 'subsample': 0.3558572181710563, 'n_estimators': 10}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:06,082] Trial 2455 finished with value: -0.5524785398907132 and parameters: {'max_depth': 15, 'gamma': 0, 'max_delta_step': 9, 'min_child_weight': 9, 'learning_rate': 0.012231553659752509, 'subsample': 0.2977318280661996, 'n_estimators': 36}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:06,177] Trial 2456 finished with value: -0.5169237537384034 and parameters: {'max_depth': 14, 'gamma': 1, 'max_delta_step': 8, 'min_child_weight': 18, 'learning_rate': 0.2052031338474027, 'subsample': 0.41664941189708254, 'n_estimators': 18}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:06,294] Trial 2457 finished with value: -0.5122929152912564 and parameters: {'max_depth': 14, 'gamma': 0, 'max_delta_step': 7, 'min_child_weight': 8, 'learning_rate': 0.14277516726900913, 'subsample': 0.3182133067999662, 'n_estimators': 31}. Best is trial 957 with value: -0.43152479924096004.
# [I 2025-08-12 23:03:06
and parameters: {'max_depth': 15, 'gamma': 0, 'max_delta_step': 7, 'min_child_weight': 20, 'learning_rate': 0.12246633375256384, 'subsample': 0.6685073400968351, 'n_estimators': 17}. Best is trial 957 with value: -0.43152479924096004.
# {'max_depth': 14,
#  'gamma': 0,
#  'max_delta_step': 8,
#  'min_child_weight': 18,
#  'learning_rate': 0.18303803924595516,
#  'subsample': 0.3060264137296991,
#  'n_estimators': 18}

# %%
sd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sd
#
# NameError: name 'sd' is not defined

# %% [markdown]
# {'max_depth': 2,
#  'gamma': 11,
#  'max_delta_step': 5,
#  'min_child_weight': 18,
#  'learning_rate': 0.37873288200618416,
#  'subsample': 0.16184011807913792,
#  'n_estimators': 225}

# %%
# We can now assess the model performance on the training set using cross validation
from sklearn.metrics import mean_squared_error
import sklearn
from sklearn import metrics

print(sklearn.metrics.get_scorer_names())

CrossValAssessor(
    scoring="neg_mean_absolute_error",
    split=BootstrapSplit(split=ClusterSplit(dataset_mers), n_bootstraps=100)
)(model_mers, dataset_mers)

# and on the test set
TestSetAssessor("neg_mean_absolute_error")(model_mers, dataset_mers)
# Out:
# ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'max_error', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_negative_likelihood_ratio', 'neg_root_mean_squared_error', 'neg_root_mean_squared_log_error', 'normalized_mutual_info_score', 'positive_likelihood_ratio', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc', 'roc_auc_ovo', 'roc_auc_ovo_weighted', 'roc_auc_ovr', 'roc_auc_ovr_weighted', 'top_k_accuracy', 'v_measure_score']
# array([-0.4315248])

# %%
# Finally, we need to fit the model on the complete dataset if we want to use it further
model_mers.fitDataset(dataset_mers)

# and save the model
_ = model_mers.save()

# %%
from qsprpred.plotting.regression import CorrelationPlot

# Instantiate with a list of models
plotter = CorrelationPlot(models=[model_mers])

# Create and optionally save/show the plot
g, summary_df = plotter.make(save=True, show=True, out_path="mers_cor_plotxg2.png")

# summary_df contains metrics like R2, RMSE per model, fold, property
print(summary_df)
# Out:
# XGMorgan_clustsplit
# /home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/qsprpred/plotting/regression.py:99: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                    Model              Fold               Property        R2  \
# 0    XGMorgan_clustsplit               0.0  pIC50 (MERS-CoV Mpro) -0.097862
# 1    XGMorgan_clustsplit               1.0  pIC50 (MERS-CoV Mpro) -0.011422
# 2    XGMorgan_clustsplit               2.0  pIC50 (MERS-CoV Mpro) -0.151531
# 3    XGMorgan_clustsplit               3.0  pIC50 (MERS-CoV Mpro)  0.002759
# 4    XGMorgan_clustsplit               4.0  pIC50 (MERS-CoV Mpro) -0.142912
# ..                   ...               ...                    ...       ...
# 96   XGMorgan_clustsplit              96.0  pIC50 (MERS-CoV Mpro)  0.182921
# 97   XGMorgan_clustsplit              97.0  pIC50 (MERS-CoV Mpro) -0.076077
# 98   XGMorgan_clustsplit              98.0  pIC50 (MERS-CoV Mpro)  0.086303
# 99   XGMorgan_clustsplit              99.0  pIC50 (MERS-CoV Mpro)  0.044585
# 100  XGMorgan_clustsplit  Independent Test  pIC50 (MERS-CoV Mpro)  0.339757
#
#          RMSE               Set
# 0    0.957091  Cross Validation
# 1    0.854180  Cross Validation
# 2    1.180050  Cross Validation
# 3    0.859140  Cross Validation
# 4    1.038918  Cross Validation
# ..        ...               ...
# 96   0.640194  Cross Validation
# 97   0.995339  Cross Validation
# 98   0.780831  Cross Validation
# 99   0.924686  Cross Validation
# 100  0.613593  Independent Test
#
# [101 rows x 6 columns]

# %%
with open("mers_test.smi", "w") as f:
    for smi in test_mers_df["SMILES"]:
        f.write(f"{smi}\n")

# %%
from rdkit import Chem
from rdkit.Chem import MolStandardize

def read_smi_file(file_path):
    smiles_list = []
    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Skip comment lines and empty lines
                if line.strip() and not line.startswith('#'):
                    # SMILES strings are typically separated by whitespace or tab
                    smiles = line.split()[0]
                    smiles_list.append(smiles)
    except FileNotFoundError:
        print("File not found.")
    return smiles_list

# Example usage to read the standardized SMILES file and create a list
file_path = 'mers_test.smi'
smiles_list = read_smi_file(file_path)
print("SMILES in the file:")
print(len(smiles_list))
# Out:
# SMILES in the file:
# 297

# %%
well = model_mers.predictMols(smiles_list)

# %%
print(well)
# Out:
# [[5.214393 ]
#  [5.2449136]
#  [4.8466496]
#  [5.017499 ]
#  [5.2743254]
#  [5.5338345]
#  [5.470039 ]
#  [5.470039 ]
#  [5.0700207]
#  [5.182725 ]
#  [5.034349 ]
#  [5.547507 ]
#  [5.5037255]
#  [5.420868 ]
#  [5.5813985]
#  [5.420868 ]
#  [5.334462 ]
#  [5.461306 ]
#  [4.9374   ]
#  [5.291135 ]
#  [5.450977 ]
#  [5.4789095]
#  [5.6758976]
#  [5.7697115]
#  [5.271351 ]
#  [5.6931424]
#  [5.6060476]
#  [5.913661 ]
#  [5.4023404]
#  [5.2570753]
#  [5.5046806]
#  [5.36801  ]
#  [5.5838327]
#  [5.526766 ]
#  [5.6360717]
#  [5.8333883]
#  [5.8314285]
#  [5.8592796]
#  [5.574784 ]
#  [5.291135 ]
#  [5.553845 ]
#  [5.979705 ]
#  [5.288113 ]
#  [5.288113 ]
#  [5.5303626]
#  [5.5303626]
#  [5.1718135]
#  [5.1718135]
#  [5.2041416]
#  [5.2041416]
#  [5.5921845]
#  [5.4278364]
#  [5.6200185]
#  [5.5111527]
#  [5.37922  ]
#  [5.537146 ]
#  [5.4585714]
#  [5.478828 ]
#  [5.574784 ]
#  [5.3876286]
#  [5.5343623]
#  [5.618201 ]
#  [5.320179 ]
#  [5.652859 ]
#  [5.453709 ]
#  [5.450977 ]
#  [5.7697115]
#  [5.921342 ]
#  [5.8314285]
#  [5.5164905]
#  [5.6614633]
#  [5.769972 ]
#  [5.746067 ]
#  [5.5789638]
#  [5.4077444]
#  [5.4018826]
#  [5.42871  ]
#  [5.9092236]
#  [5.4933076]
#  [5.7417245]
#  [5.455789 ]
#  [5.49337  ]
#  [5.8882   ]
#  [5.4988065]
#  [5.8771367]
#  [6.0009437]
#  [5.450977 ]
#  [5.778354 ]
#  [5.729352 ]
#  [5.798567 ]
#  [5.836865 ]
#  [5.7697115]
#  [5.836865 ]
#  [5.8167996]
#  [5.433543 ]
#  [5.874446 ]
#  [5.874446 ]
#  [5.7697115]
#  [5.7697115]
#  [5.704944 ]
#  [5.836865 ]
#  [5.874446 ]
#  [5.8167996]
#  [5.7697115]
#  [5.777794 ]
#  [5.855282 ]
#  [5.6638155]
#  [6.0009437]
#  [6.2181945]
#  [5.2971883]
#  [5.1977563]
#  [6.2155676]
#  [5.433543 ]
#  [5.769972 ]
#  [5.39799  ]
#  [5.7697115]
#  [5.2743254]
#  [5.2743254]
#  [5.3079567]
#  [5.0604753]
#  [5.0604753]
#  [6.2122045]
#  [5.2703724]
#  [6.0733037]
#  [5.2568917]
#  [5.0604753]
#  [5.2743254]
#  [5.3981323]
#  [5.0120234]
#  [4.8449254]
#  [6.1849413]
#  [4.6367064]
#  [4.554285 ]
#  [4.880526 ]
#  [4.267331 ]
#  [4.7339773]
#  [4.8650856]
#  [4.8373556]
#  [4.677664 ]
#  [4.584658 ]
#  [4.6572266]
#  [4.80315  ]
#  [4.8188267]
#  [5.216072 ]
#  [5.1152635]
#  [4.6220555]
#  [4.972028 ]
#  [4.53851  ]
#  [4.7148757]
#  [4.9489346]
#  [5.511853 ]
#  [4.8934345]
#  [4.8934345]
#  [4.525732 ]
#  [4.9007235]
#  [5.046909 ]
#  [4.9883304]
#  [4.8749094]
#  [4.9910603]
#  [4.9910603]
#  [4.8188267]
#  [4.4522595]
#  [4.8902564]
#  [4.7641068]
#  [4.9376793]
#  [4.6909738]
#  [4.8188267]
#  [4.8724537]
#  [4.7050242]
#  [4.7595987]
#  [5.1152635]
#  [4.9510584]
#  [4.9253254]
#  [4.7147975]
#  [6.186563 ]
#  [4.932147 ]
#  [4.8747263]
#  [6.207408 ]
#  [4.905449 ]
#  [6.207408 ]
#  [4.9510584]
#  [5.0472255]
#  [6.3055434]
#  [4.6709976]
#  [6.279849 ]
#  [6.3737106]
#  [4.339213 ]
#  [4.936743 ]
#  [5.192123 ]
#  [4.5518756]
#  [4.400651 ]
#  [4.9510584]
#  [4.2974534]
#  [4.9782166]
#  [5.0545783]
#  [4.5383854]
#  [5.006257 ]
#  [4.6250415]
#  [4.789921 ]
#  [5.028869 ]
#  [5.028869 ]
#  [4.6250415]
#  [4.728256 ]
#  [4.235975 ]
#  [4.7369742]
#  [4.4799156]
#  [4.4514976]
#  [5.062737 ]
#  [4.4799156]
#  [4.715229 ]
#  [4.6876545]
#  [4.7750115]
#  [4.6165233]
#  [4.6165233]
#  [4.6198378]
#  [4.6198378]
#  [4.4982557]
#  [4.4982557]
#  [5.082762 ]
#  [4.6374335]
#  [4.6374335]
#  [4.692259 ]
#  [4.692259 ]
#  [4.4514976]
#  [4.539998 ]
#  [4.3646717]
#  [4.8204603]
#  [4.8204603]
#  [4.7863193]
#  [4.674727 ]
#  [4.674727 ]
#  [4.4754763]
#  [4.4754763]
#  [5.070832 ]
#  [4.1280985]
#  [4.851513 ]
#  [4.500628 ]
#  [4.500628 ]
#  [4.777711 ]
#  [5.023389 ]
#  [4.53841  ]
#  [4.555388 ]
#  [4.555388 ]
#  [4.652892 ]
#  [5.3168945]
#  [5.105604 ]
#  [4.951653 ]
#  [4.9876313]
#  [4.7984095]
#  [4.6463327]
#  [4.7015185]
#  [4.956192 ]
#  [4.956192 ]
#  [4.8120265]
#  [4.548149 ]
#  [4.6579843]
#  [4.867278 ]
#  [5.082762 ]
#  [4.3646717]
#  [4.7942085]
#  [4.4495883]
#  [4.3791385]
#  [4.53841  ]
#  [4.8014417]
#  [4.773799 ]
#  [5.349925 ]
#  [4.4495883]
#  [4.4495883]
#  [4.820097 ]
#  [4.23927  ]
#  [4.3943043]
#  [4.6472044]
#  [4.8767705]
#  [4.2393055]
#  [4.6770325]
#  [4.6838937]
#  [4.1267953]
#  [4.5709147]
#  [4.5709147]
#  [4.5709147]
#  [4.5709147]
#  [5.011987 ]
#  [4.965118 ]
#  [4.9363127]
#  [4.586115 ]
#  [4.965118 ]
#  [4.238022 ]
#  [4.238022 ]
#  [4.9080048]
#  [4.553924 ]
#  [4.6907787]
#  [4.6907787]
#  [4.6907787]
#  [4.6907787]
#  [4.238022 ]
#  [5.2397175]
#  [5.2397175]]

# %%
min_length = min(len(smiles_list), len(well))
values = [val[0] for val in well[:min_length]]

# %%
print(values)
# Out:
# [5.214393, 5.2449136, 4.8466496, 5.017499, 5.2743254, 5.5338345, 5.470039, 5.470039, 5.0700207, 5.182725, 5.034349, 5.547507, 5.5037255, 5.420868, 5.5813985, 5.420868, 5.334462, 5.461306, 4.9374, 5.291135, 5.450977, 5.4789095, 5.6758976, 5.7697115, 5.271351, 5.6931424, 5.6060476, 5.913661, 5.4023404, 5.2570753, 5.5046806, 5.36801, 5.5838327, 5.526766, 5.6360717, 5.8333883, 5.8314285, 5.8592796, 5.574784, 5.291135, 5.553845, 5.979705, 5.288113, 5.288113, 5.5303626, 5.5303626, 5.1718135, 5.1718135, 5.2041416, 5.2041416, 5.5921845, 5.4278364, 5.6200185, 5.5111527, 5.37922, 5.537146, 5.4585714, 5.478828, 5.574784, 5.3876286, 5.5343623, 5.618201, 5.320179, 5.652859, 5.453709, 5.450977, 5.7697115, 5.921342, 5.8314285, 5.5164905, 5.6614633, 5.769972, 5.746067, 5.5789638, 5.4077444, 5.4018826, 5.42871, 5.9092236, 5.4933076, 5.7417245, 5.455789, 5.49337, 5.8882, 5.4988065, 5.8771367, 6.0009437, 5.450977, 5.778354, 5.729352, 5.798567, 5.836865, 5.7697115, 5.836865, 5.8167996, 5.433543, 5.874446, 5.874446, 5.7697115, 5.7697115, 5.704944, 5.836865, 5.874446, 5.8167996, 5.7697115, 5.777794, 5.855282, 5.6638155, 6.0009437, 6.2181945, 5.2971883, 5.1977563, 6.2155676, 5.433543, 5.769972, 5.39799, 5.7697115, 5.2743254, 5.2743254, 5.3079567, 5.0604753, 5.0604753, 6.2122045, 5.2703724, 6.0733037, 5.2568917, 5.0604753, 5.2743254, 5.3981323, 5.0120234, 4.8449254, 6.1849413, 4.6367064, 4.554285, 4.880526, 4.267331, 4.7339773, 4.8650856, 4.8373556, 4.677664, 4.584658, 4.6572266, 4.80315, 4.8188267, 5.216072, 5.1152635, 4.6220555, 4.972028, 4.53851, 4.7148757, 4.9489346, 5.511853, 4.8934345, 4.8934345, 4.525732, 4.9007235, 5.046909, 4.9883304, 4.8749094, 4.9910603, 4.9910603, 4.8188267, 4.4522595, 4.8902564, 4.7641068, 4.9376793, 4.6909738, 4.8188267, 4.8724537, 4.7050242, 4.7595987, 5.1152635, 4.9510584, 4.9253254, 4.7147975, 6.186563, 4.932147, 4.8747263, 6.207408, 4.905449, 6.207408, 4.9510584, 5.0472255, 6.3055434, 4.6709976, 6.279849, 6.3737106, 4.339213, 4.936743, 5.192123, 4.5518756, 4.400651, 4.9510584, 4.2974534, 4.9782166, 5.0545783, 4.5383854, 5.006257, 4.6250415, 4.789921, 5.028869, 5.028869, 4.6250415, 4.728256, 4.235975, 4.7369742, 4.4799156, 4.4514976, 5.062737, 4.4799156, 4.715229, 4.6876545, 4.7750115, 4.6165233, 4.6165233, 4.6198378, 4.6198378, 4.4982557, 4.4982557, 5.082762, 4.6374335, 4.6374335, 4.692259, 4.692259, 4.4514976, 4.539998, 4.3646717, 4.8204603, 4.8204603, 4.7863193, 4.674727, 4.674727, 4.4754763, 4.4754763, 5.070832, 4.1280985, 4.851513, 4.500628, 4.500628, 4.777711, 5.023389, 4.53841, 4.555388, 4.555388, 4.652892, 5.3168945, 5.105604, 4.951653, 4.9876313, 4.7984095, 4.6463327, 4.7015185, 4.956192, 4.956192, 4.8120265, 4.548149, 4.6579843, 4.867278, 5.082762, 4.3646717, 4.7942085, 4.4495883, 4.3791385, 4.53841, 4.8014417, 4.773799, 5.349925, 4.4495883, 4.4495883, 4.820097, 4.23927, 4.3943043, 4.6472044, 4.8767705, 4.2393055, 4.6770325, 4.6838937, 4.1267953, 4.5709147, 4.5709147, 4.5709147, 4.5709147, 5.011987, 4.965118, 4.9363127, 4.586115, 4.965118, 4.238022, 4.238022, 4.9080048, 4.553924, 4.6907787, 4.6907787, 4.6907787, 4.6907787, 4.238022, 5.2397175, 5.2397175]

# %%
import csv
# Write to CSV file
with open("mers_prediction_final_xg.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["SMILES", "MERS"])
    for smiles, value in zip(smiles_list, values):
        writer.writerow([smiles, value])

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
pd.read_csv("mers_prediction_final_xg.csv")
# Out:
#                                                 SMILES      MERS
# 0    C=CC(=O)Nc1cccc(N(Cc2cccc(Cl)c2)C(=O)Cc2cncc3c...  5.214393
# 1    CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...  5.244914
# 2    CNC(=O)CN1C[C@]2(CCN(c3cncc4ccc(OC[C@H](O)CN(C...  4.846650
# 3    CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...  5.017499
# 4    CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...  5.274325
# ..                                                 ...       ...
# 292        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1  4.690779
# 293        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1  4.690779
# 294        O=C(Cc1cncc2ccccc12)N1CCC[C@H]2CCCC[C@@H]21  4.238022
# 295  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12  5.239718
# 296  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12  5.239718
#
# [297 rows x 2 columns]

# %%
test_mers_df["predicted MERS"] = values

# %%
test_mers_df.to_csv("mers_predicted_true_xg.csv")

# %% [markdown]
# The End.
