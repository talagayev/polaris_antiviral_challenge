# %% [markdown]
# # Ligand ADMET and Potency (Property Prediction)
#
# The [ADMET](https://polarishub.io/competitions/asap-discovery/antiviral-admet-2025) and [Potency](https://polarishub.io/competitions/asap-discovery/antiviral-potency-2025) Challenge of the [ASAP Discovery competition](https://polarishub.io/blog/antiviral-competition) take the shape of a property prediction task. Given the SMILES (or, to be more precise, the CXSMILES) of a molecule, you are asked to predict the numerical properties of said molecule. This is a relatively straight-forward application of ML and this notebook will quickly get you up and running!
#
# To begin with, choose one of the two challenges! The code will look the same for both.

# %% [markdown]
# As suggested in the logs, we'll cache the dataset. Note that this is not strictly necessary, but it does speed up later steps.

# %%
import pandas as pd

potency_df = pd.read_csv("antiviral_potency_2025.csv")

# %%
potency_df
# Out:
#                                                CXSMILES Molecule Name    Set  \
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...  ASAP-0000141  Train
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000142  Train
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...  ASAP-0000143  Train
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000144  Train
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...  ASAP-0000145  Train
# ...                                                 ...           ...    ...
# 1323  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032561   Test
# 1324  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032562   Test
# 1325  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...  ASAP-0032572   Test
# 1326  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032604   Test
# 1327  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032605   Test
#
#       pIC50 (MERS-CoV Mpro)  pIC50 (SARS-CoV-2 Mpro)
# 0                      4.19                      NaN
# 1                      4.92                     5.29
# 2                      4.73                      NaN
# 3                      4.90                     6.11
# 4                      4.81                     5.62
# ...                     ...                      ...
# 1323                   4.54                     4.20
# 1324                   4.42                      NaN
# 1325                   4.84                     5.18
# 1326                   5.53                     5.59
# 1327                   5.47                     5.77
#
# [1328 rows x 5 columns]

# %%
train_df = potency_df[potency_df['Set'] == 'Train'].rename(columns={'CXSMILES': 'SMILES'})

# %%
test_sars_df = (
    potency_df[
        (potency_df['Set'] == 'Test') &
        (potency_df['pIC50 (SARS-CoV-2 Mpro)'].notna())
    ]
    .rename(columns={'CXSMILES': 'SMILES'})
)

# %%
test_sars_df
# Out:
#                                                  SMILES Molecule Name   Set  \
# 1031  C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...  ASAP-0000175  Test
# 1033  CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...  ASAP-0000528  Test
# 1034  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000541  Test
# 1035  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...  ASAP-0000733  Test
# 1036  CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[...  ASAP-0000738  Test
# ...                                                 ...           ...   ...
# 1322  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032560  Test
# 1323  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...  ASAP-0032561  Test
# 1325  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...  ASAP-0032572  Test
# 1326  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032604  Test
# 1327  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...  ASAP-0032605  Test
#
#       pIC50 (MERS-CoV Mpro)  pIC50 (SARS-CoV-2 Mpro)
# 1031                   5.52                     5.57
# 1033                   5.80                     7.44
# 1034                   5.81                     6.48
# 1035                   6.69                     7.87
# 1036                   5.98                     7.60
# ...                     ...                      ...
# 1322                   4.33                     4.02
# 1323                   4.54                     4.20
# 1325                   4.84                     5.18
# 1326                   5.53                     5.59
# 1327                   5.47                     5.77
#
# [263 rows x 5 columns]

# %%
train_df.to_csv("potency_training_unblinded.csv")

# %% [markdown]
# ### Raw data dump
# We've decided to sacrifice the completeness of the scientific data to improve its ease of use. For those that are interested, you can also access the raw data dump that this dataset has been created from.

# %% [markdown]
# ## Build a model
# Next, we'll train a simple baseline model using scikit-learn.
#
# You'll notice that the challenge has multiple targets.

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

# %%
sars_props = [
    {"name": "pIC50 (SARS-CoV-2 Mpro)", "task": "REGRESSION"},]

# %% [markdown]
# ## MERS Model Generation

# %% [markdown]
# Create for PCA QSPRDataset of test and training with known Descriptors, which were previously calculated

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

dataset_test_sars = QSPRDataset(
    name="MultiTaskTutorialDataset",
    target_props=sars_props,
    df=test_sars_df,
    store_dir="sars_output_adjusted_22/data_test",
    overwrite=True
)


dataset_test_sars.getDF()
# Out:
#                                                                          SMILES  \
# QSPRID
# MultiTaskTutorialDataset_000  C=CC(=O)NC1=CC=CC(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=...
# MultiTaskTutorialDataset_001  CNC(=O)CN1C[C@]2(CCN(C3=CN=CC4=CC=C(OC[C@H](O)...
# MultiTaskTutorialDataset_002  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# MultiTaskTutorialDataset_003  CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C...
# MultiTaskTutorialDataset_004  CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[...
# ...                                                                         ...
# MultiTaskTutorialDataset_258  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# MultiTaskTutorialDataset_259  O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1[C@H]1CCC...
# MultiTaskTutorialDataset_260  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCCC[C@@H]...
# MultiTaskTutorialDataset_261  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
# MultiTaskTutorialDataset_262  COC1=CC=CC=C1[C@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC...
#
#                              Molecule Name   Set  pIC50 (MERS-CoV Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000  ASAP-0000175  Test                   5.52
# MultiTaskTutorialDataset_001  ASAP-0000528  Test                   5.80
# MultiTaskTutorialDataset_002  ASAP-0000541  Test                   5.81
# MultiTaskTutorialDataset_003  ASAP-0000733  Test                   6.69
# MultiTaskTutorialDataset_004  ASAP-0000738  Test                   5.98
# ...                                    ...   ...                    ...
# MultiTaskTutorialDataset_258  ASAP-0032560  Test                   4.33
# MultiTaskTutorialDataset_259  ASAP-0032561  Test                   4.54
# MultiTaskTutorialDataset_260  ASAP-0032572  Test                   4.84
# MultiTaskTutorialDataset_261  ASAP-0032604  Test                   5.53
# MultiTaskTutorialDataset_262  ASAP-0032605  Test                   5.47
#
#                               pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000                     5.57
# MultiTaskTutorialDataset_001                     7.44
# MultiTaskTutorialDataset_002                     6.48
# MultiTaskTutorialDataset_003                     7.87
# MultiTaskTutorialDataset_004                     7.60
# ...                                               ...
# MultiTaskTutorialDataset_258                     4.02
# MultiTaskTutorialDataset_259                     4.20
# MultiTaskTutorialDataset_260                     5.18
# MultiTaskTutorialDataset_261                     5.59
# MultiTaskTutorialDataset_262                     5.77
#
#                                                     QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_000  MultiTaskTutorialDataset_000
# MultiTaskTutorialDataset_001  MultiTaskTutorialDataset_001
# MultiTaskTutorialDataset_002  MultiTaskTutorialDataset_002
# MultiTaskTutorialDataset_003  MultiTaskTutorialDataset_003
# MultiTaskTutorialDataset_004  MultiTaskTutorialDataset_004
# ...                                                    ...
# MultiTaskTutorialDataset_258  MultiTaskTutorialDataset_258
# MultiTaskTutorialDataset_259  MultiTaskTutorialDataset_259
# MultiTaskTutorialDataset_260  MultiTaskTutorialDataset_260
# MultiTaskTutorialDataset_261  MultiTaskTutorialDataset_261
# MultiTaskTutorialDataset_262  MultiTaskTutorialDataset_262
#
#                               pIC50 (SARS-CoV-2 Mpro)_original
# QSPRID
# MultiTaskTutorialDataset_000                              5.57
# MultiTaskTutorialDataset_001                              7.44
# MultiTaskTutorialDataset_002                              6.48
# MultiTaskTutorialDataset_003                              7.87
# MultiTaskTutorialDataset_004                              7.60
# ...                                                        ...
# MultiTaskTutorialDataset_258                              4.02
# MultiTaskTutorialDataset_259                              4.20
# MultiTaskTutorialDataset_260                              5.18
# MultiTaskTutorialDataset_261                              5.59
# MultiTaskTutorialDataset_262                              5.77
#
# [263 rows x 7 columns]

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_test_sars)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_test_sars.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=5, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_test_sars.y)}")
print(f"Number of samples test set: {len(dataset_test_sars.y_ind)}")

print(type(dataset_test_sars.X))
print(dataset_test_sars.X.shape)
print(dataset_test_sars.X_ind.shape)


dataset_test_sars.save()
# Out:
# Number of samples train set: 210
# Number of samples test set: 53
# <class 'pandas.core.frame.DataFrame'>
# (210, 1280)
# (53, 1280)

# %%
from qsprpred.data import QSPRDataset
from sklearn.impute import SimpleImputer

dataset_sars = QSPRDataset(
    name="MultiTaskTutorialDataset",
    target_props=sars_props,
    df=train_df,
    store_dir="sars_output_adjusted_22/data",
    overwrite=True
)


dataset_sars.getDF()
# Out:
#                                                                           SMILES  \
# QSPRID
# MultiTaskTutorialDataset_0001  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# MultiTaskTutorialDataset_0003  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# MultiTaskTutorialDataset_0004  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...
# MultiTaskTutorialDataset_0005  C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC...
# MultiTaskTutorialDataset_0006  C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC...
# ...                                                                          ...
# MultiTaskTutorialDataset_1021  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC([C@H]2CCOC2)CC1...
# MultiTaskTutorialDataset_1022            O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC2(CC2)C1
# MultiTaskTutorialDataset_1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...
# MultiTaskTutorialDataset_1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...
# MultiTaskTutorialDataset_1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...
#
#                               Molecule Name    Set  pIC50 (MERS-CoV Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_0001  ASAP-0000142  Train                   4.92
# MultiTaskTutorialDataset_0003  ASAP-0000144  Train                   4.90
# MultiTaskTutorialDataset_0004  ASAP-0000145  Train                   4.81
# MultiTaskTutorialDataset_0005  ASAP-0000146  Train                   4.88
# MultiTaskTutorialDataset_0006  ASAP-0000147  Train                   4.81
# ...                                     ...    ...                    ...
# MultiTaskTutorialDataset_1021  ASAP-0031882  Train                   4.27
# MultiTaskTutorialDataset_1022  ASAP-0031887  Train                   4.11
# MultiTaskTutorialDataset_1026  ASAP-0031916  Train                   5.57
# MultiTaskTutorialDataset_1027  ASAP-0031917  Train                   4.60
# MultiTaskTutorialDataset_1029  ASAP-0031920  Train                   4.40
#
#                                pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_0001                     5.29
# MultiTaskTutorialDataset_0003                     6.11
# MultiTaskTutorialDataset_0004                     5.62
# MultiTaskTutorialDataset_0005                     6.45
# MultiTaskTutorialDataset_0006                     5.56
# ...                                                ...
# MultiTaskTutorialDataset_1021                     4.68
# MultiTaskTutorialDataset_1022                     4.41
# MultiTaskTutorialDataset_1026                     6.38
# MultiTaskTutorialDataset_1027                     6.09
# MultiTaskTutorialDataset_1029                     5.06
#
#                                                       QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_0001  MultiTaskTutorialDataset_0001
# MultiTaskTutorialDataset_0003  MultiTaskTutorialDataset_0003
# MultiTaskTutorialDataset_0004  MultiTaskTutorialDataset_0004
# MultiTaskTutorialDataset_0005  MultiTaskTutorialDataset_0005
# MultiTaskTutorialDataset_0006  MultiTaskTutorialDataset_0006
# ...                                                      ...
# MultiTaskTutorialDataset_1021  MultiTaskTutorialDataset_1021
# MultiTaskTutorialDataset_1022  MultiTaskTutorialDataset_1022
# MultiTaskTutorialDataset_1026  MultiTaskTutorialDataset_1026
# MultiTaskTutorialDataset_1027  MultiTaskTutorialDataset_1027
# MultiTaskTutorialDataset_1029  MultiTaskTutorialDataset_1029
#
#                                pIC50 (SARS-CoV-2 Mpro)_original
# QSPRID
# MultiTaskTutorialDataset_0001                              5.29
# MultiTaskTutorialDataset_0003                              6.11
# MultiTaskTutorialDataset_0004                              5.62
# MultiTaskTutorialDataset_0005                              6.45
# MultiTaskTutorialDataset_0006                              5.56
# ...                                                         ...
# MultiTaskTutorialDataset_1021                              4.68
# MultiTaskTutorialDataset_1022                              4.41
# MultiTaskTutorialDataset_1026                              6.38
# MultiTaskTutorialDataset_1027                              6.09
# MultiTaskTutorialDataset_1029                              5.06
#
# [842 rows x 7 columns]

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_sars)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_sars.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=5, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_sars.y)}")
print(f"Number of samples test set: {len(dataset_sars.y_ind)}")

print(type(dataset_sars.X))
print(dataset_sars.X.shape)
print(dataset_sars.X_ind.shape)


dataset_sars.save()
# Out:
# Number of samples train set: 672
# Number of samples test set: 170
# <class 'pandas.core.frame.DataFrame'>
# (672, 1280)
# (170, 1280)

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_sars)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_sars.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=5, nBits=256)],
    recalculate_features=True,
)

print(f"Number of samples train set: {len(dataset_sars.y)}")
print(f"Number of samples test set: {len(dataset_sars.y_ind)}")

print(type(dataset_sars.X))
print(dataset_sars.X.shape)
print(dataset_sars.X_ind.shape)


dataset_sars.save()
# Out:
# Number of samples train set: 672
# Number of samples test set: 170
# <class 'pandas.core.frame.DataFrame'>
# (672, 1280)
# (170, 1280)

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Combine train and test for X into one "Train"
X_all_train = np.vstack([dataset_sars.X, dataset_sars.X_ind])

# Combine train and test for Y into one "Test"
X_all_test = np.vstack([dataset_test_sars.X, dataset_test_sars.X_ind])

# Fit PCA on combined space so both sets are projected in same PC space
X_combined = np.vstack([X_all_train, X_all_test])
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_combined)

# Separate transformed "train" and "test"
X_train_pca = X_pca[:len(X_all_train)]
X_test_pca = X_pca[len(X_all_train):]

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], 
            alpha=0.6, label='Train', c='blue')
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], 
            alpha=0.6, label='Test', c='red')

plt.xlabel(f"PC1")
plt.ylabel(f"PC2")
plt.title("PCA of Molecular Fingerprints for SARS-CoV-2 MPro")
plt.legend()

plt.savefig("PCA_train_test_sars2.png", dpi=300)
plt.show()

# %%
from qsprpred.data import RandomSplit, BootstrapSplit, ScaffoldSplit, ClusterSplit
from qsprpred.data.descriptors.fingerprints import MorganFP, RDKitFP
from qsprpred.data.processing.feature_filters import LowVarianceFilter
from sklearn.preprocessing import StandardScaler

# Specifiy random split for creating the train (80%) and test set (20%)
rand_split = ClusterSplit(test_fraction=0.2, dataset=dataset_sars)
# rand_split = RandomSplit(test_fraction=0.15, dataset=dataset_mers)

# calculate compound features and split dataset into train and test
dataset_sars.prepareDataset(
    split=rand_split,
    feature_calculators=[MorganFP(radius=3, nBits=1024), RDKitFP(maxPath=5, nBits=256)],
    recalculate_features=True,
    feature_filters=[LowVarianceFilter(0.001)],
    feature_standardizer=StandardScaler()
)

print(f"Number of samples train set: {len(dataset_sars.y)}")
print(f"Number of samples test set: {len(dataset_sars.y_ind)}")

print(type(dataset_sars.X))
print(dataset_sars.X.shape)
print(dataset_sars.X_ind.shape)


dataset_sars.save()
# Out:
# Number of samples train set: 672
# Number of samples test set: 170
# <class 'pandas.core.frame.DataFrame'>
# (672, 1170)
# (170, 1170)

# %%
from qsprpred.models import SklearnModel
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor
from qsprpred.models import CrossValAssessor, TestSetAssessor

os.makedirs("class_models/XG_models_clust_sars_test", exist_ok=True)

# This is an SKlearn model, so we will initialize it with the SklearnModel class
model_sars = SklearnModel(
    base_dir="class_models/XG_models_clust_sars_test",
    alg=XGBRegressor,
    name="XGMorgan_clustsplit"
)

import numpy as np
from qsprpred.models import GridSearchOptimization, CrossValAssessor

# %%
from qsprpred.models import OptunaOptimization, TestSetAssessor
from sklearn.model_selection import KFold

# Note the specification of the hyperparameter types as first item in the list
search_space = {"max_depth": ["int", 1, 20],
                "gamma": ["int", 0, 20],
                "max_delta_step": ["int", 0, 20],
                "min_child_weight": ["int", 1, 20],
                "learning_rate": ["float", 0.001, 1],
                "subsample": ["float", 0.001, 1],
                "n_estimators": ["int", 10, 250],
               }

# Optuna gridsearcher with the TestSetAssessor
gridsearcher = OptunaOptimization(
    n_trials=2500,
    param_grid=search_space,
    model_assessor=TestSetAssessor(scoring='neg_mean_absolute_error'),
)
gridsearcher.optimize(model_sars, dataset_sars)
# Out:
# [I 2025-08-12 00:48:50,557] A new study created in memory with name: no-name-2cfa0966-4b86-44f8-b90e-ab0e4c0924c7
# [I 2025-08-12 00:48:50,719] Trial 0 finished with value: -0.69956399121004 and parameters: {'max_depth': 8, 'gamma': 18, 'max_delta_step': 15, 'min_child_weight': 18, 'learning_rate': 0.5403079718093555, 'subsample': 0.8630181588461313, 'n_estimators': 187}. Best is trial 0 with value: -0.69956399121004.
# [I 2025-08-12 00:48:50,759] Trial 1 finished with value: -0.7042810429965748 and parameters: {'max_depth': 13, 'gamma': 15, 'max_delta_step': 10, 'min_child_weight': 17, 'learning_rate': 0.8315506533130161, 'subsample': 0.22873718788578043, 'n_estimators': 94}. Best is trial 0 with value: -0.69956399121004.
# [I 2025-08-12 00:48:50,777] Trial 2 finished with value: -0.6562682541117949 and parameters: {'max_depth': 13, 'gamma': 16, 'max_delta_step': 18, 'min_child_weight': 10, 'learning_rate': 0.43734569215749003, 'subsample': 0.4219530647713299, 'n_estimators': 26}. Best is trial 2 with value: -0.6562682541117949.
# [I 2025-08-12 00:48:50,832] Trial 3 finished with value: -0.6668879612193388 and parameters: {'max_depth': 13, 'gamma': 14, 'max_delta_step': 0, 'min_child_weight': 11, 'learning_rate': 0.7144262529582195, 'subsample': 0.3603572863455143, 'n_estimators': 171}. Best is trial 2 with value: -0.6562682541117949.
# [I 2025-08-12 00:48:50,899] Trial 4 finished with value: -0.6458037811728085 and parameters: {'max_depth': 20, 'gamma': 18, 'max_delta_step': 2, 'min_child_weight': 17, 'learning_rate': 0.5317613479783825, 'subsample': 0.39876969671686613, 'n_estimators': 245}. Best is trial 4 with value: -0.6458037811728085.
# [I 2025-08-12 00:48:50,980] Trial 5 finished with value: -1.4421165937535902 and parameters: {'max_depth': 2, 'gamma': 1, 'max_delta_step': 5, 'min_child_weight':
. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,498] Trial 49 finished with value: -0.8086355917874506 and parameters: {'max_depth': 18, 'gamma': 1, 'max_delta_step': 10, 'min_child_weight': 13, 'learning_rate': 0.9750705207019756, 'subsample': 0.82700819499538, 'n_estimators': 224}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,567] Trial 50 finished with value: -0.6600104440801283 and parameters: {'max_depth': 16, 'gamma': 6, 'max_delta_step': 17, 'min_child_weight': 5, 'learning_rate': 0.19095360640392992, 'subsample': 0.6793682526397674, 'n_estimators': 211}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,640] Trial 51 finished with value: -0.6417920505860272 and parameters: {'max_depth': 4, 'gamma': 2, 'max_delta_step': 8, 'min_child_weight': 18, 'learning_rate': 0.5196510672713301, 'subsample': 0.6648933144629005, 'n_estimators': 237}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,720] Trial 52 finished with value: -0.6790194313946892 and parameters: {'max_depth': 18, 'gamma': 3, 'max_delta_step': 8, 'min_child_weight': 16, 'learning_rate': 0.373332738537545, 'subsample': 0.6017244799254058, 'n_estimators': 241}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,763] Trial 53 finished with value: -0.6931810255611643 and parameters: {'max_depth': 14, 'gamma': 15, 'max_delta_step': 6, 'min_child_weight': 19, 'learning_rate': 0.30957649634239626, 'subsample': 0.6547316345488812, 'n_estimators': 111}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:54,831] Trial 54 finished with value: -0.6161210499931784 and parameters: {'max_depth': 10, 'gamma': 2, 'max_delta_step': 12, 'min_child_weight': 20, 'learning_rate': 0.43806551686548906, 'subsample': 0.5592767601022566, 'n_estimators': 241}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:55,069] Trial 55 finished with value: -0.6247638021356918 and parameters: {'max_depth': 17, 'gamma': 0, 'max_delta_step': 11, 'min_child_weight': 17, 'learning_rate': 0.11833657397312222, 'subsample': 0.7673243629926738, 'n_estimators': 228}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:55,137] Trial 56 finished with value: -0.6372133601693546 and parameters: {'max_depth': 19, 'gamma': 3, 'max_delta_step': 7, 'min_child_weight': 19, 'learning_rate': 0.1562826414248477, 'subsample': 0.7100826535863171, 'n_estimators': 241}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:55,239] Trial 57 finished with value: -0.6117045767167035 and parameters: {'max_depth': 20, 'gamma': 1, 'max_delta_step': 6, 'min_child_weight': 18, 'learning_rate': 0.06404207655154172, 'subsample': 0.535401536293241, 'n_estimators': 216}. Best is trial 11 with value: -0.6062434234619141.
# [I 2025-08-12 00:48:55,360] Trial 58 finished with value: -0.588997423508588 and parameters: {'max_depth': 20, 'gamma': 1, 'max_delta_step': 4, 'min_child_weight': 16, 'learning_rate': 0.06687650960020791, 'subsample': 0.3639133905876067, 'n_estimators': 201}. Best is trial 58 with value: -0.588997423508588.
# [I 2025-08-12 00:48:55,477] Trial 59 finished with value: -0.5838916268068202 and parameters: {'max_depth': 20, 'gamma': 1, 'max_delta_step': 3, 'min_child_weight': 16, 'learning_rate': 0.06891826551650379, 'subsample': 0.34615898352340985, 'n_estimators': 200}. Best is trial 59 with value: -0.5838916268068202.
# [I 2025-08-12 00:48:55,626] Trial 60 finished with value: -0.5879572119993322 and parameters: {'max_depth': 20, 'gamma': 0, 'max_delta_step': 3, 'min_child_weight': 14, 'learning_rate': 0.04635535082279372, 'subsample': 0.3080557228943991, 'n_estimators': 179}. Best is trial 59 with value: -0.5838916268068202.
# [I 2025-08-12 00:48:55,781] Trial 61 finished with value: -0.5915916139939252 and parameters: {'max_depth': 20, 'gamma': 0, 'max_delta_step': 3, 'min_child_weight': 14, 'learning_rate': 0.03313682569984339, 'subsample': 0.3384413434316661, 'n_estimators': 180}. Best is trial 59 with value: -0.5838916268068202.
# [I 2025-08-12 00:48:55,923] Trial 62 finished with value: -0.60932109709347 and parameters: {'max_depth': 20, 'gamma': 0, 'max_delta_step': 3, 'min_child_weight': 13, 'learning_rate': 0.02267111614513744, 'subsample': 0.29460721079170343, 'n_estimators': 177}. Best is trial 59 with value: -0.5838916268068202.
# [I 2025-08-12 00:48:56,077] Trial 63 finished with value: -0.6009789341197295 and parameters: {'max_depth': 20, 'gamma': 0, 'max_delta_step': 3, 'min_child_weight': 13, 'learning_rate': 0.03255143525653257, 'subsample': 0.33823722276304685, 'n_estimators': 183}. Best is trial 59 with value: -0.5838916268068202.
# [I 2025-08-12 00:48:56,227] Trial 64 finished with value: -0.603580514346852 and parameters: {'max_depth': 20, 'gamma': 0, 'max_delta_step':
 'gamma': 1, 'max_delta_step': 13, 'min_child_weight': 5, 'learning_rate': 0.07967752842965414, 'subsample': 0.4317738235613455, 'n_estimators': 185}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:19,638] Trial 2486 finished with value: -0.6156175305983599 and parameters: {'max_depth': 16, 'gamma': 2, 'max_delta_step': 12, 'min_child_weight': 13, 'learning_rate': 0.09440412858516874, 'subsample': 0.5039495609015218, 'n_estimators': 112}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:19,886] Trial 2487 finished with value: -0.5656256533230052 and parameters: {'max_depth': 11, 'gamma': 0, 'max_delta_step': 15, 'min_child_weight': 14, 'learning_rate': 0.12700552781877034, 'subsample': 0.39007877239742766, 'n_estimators': 215}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:20,140] Trial 2488 finished with value: -0.5769034779492547 and parameters: {'max_depth': 12, 'gamma': 0, 'max_delta_step': 11, 'min_child_weight': 11, 'learning_rate': 0.06490011406835604, 'subsample': 0.450949602366563, 'n_estimators': 202}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:20,381] Trial 2489 finished with value: -0.5846854351268096 and parameters: {'max_depth': 18, 'gamma': 0, 'max_delta_step': 13, 'min_child_weight': 12, 'learning_rate': 0.042860572937275666, 'subsample': 0.410065814809865, 'n_estimators': 150}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:20,518] Trial 2490 finished with value: -0.6482781015283922 and parameters: {'max_depth': 17, 'gamma': 6, 'max_delta_step': 14, 'min_child_weight': 14, 'learning_rate': 0.08550761293959909, 'subsample': 0.47777435406470725, 'n_estimators': 160}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:20,668] Trial 2491 finished with value: -0.5865124061808866 and parameters: {'max_depth': 17, 'gamma': 1, 'max_delta_step': 14, 'min_child_weight': 6, 'learning_rate': 0.12049981617042611, 'subsample': 0.436168970113517, 'n_estimators': 121}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:20,932] Trial 2492 finished with value: -0.5911919863083783 and parameters: {'max_depth': 18, 'gamma': 0, 'max_delta_step': 11, 'min_child_weight': 13, 'learning_rate': 0.06025087657870136, 'subsample': 0.3486926117904735, 'n_estimators': 209}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:21,156] Trial 2493 finished with value: -1.2358082592627582 and parameters: {'max_depth': 16, 'gamma': 0, 'max_delta_step': 15, 'min_child_weight': 12, 'learning_rate': 0.9997773701855426, 'subsample': 0.4609662441520463, 'n_estimators': 141}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:21,367] Trial 2494 finished with value: -0.6101998007157269 and parameters: {'max_depth': 16, 'gamma': 1, 'max_delta_step': 13, 'min_child_weight': 14, 'learning_rate': 0.022279740465066124, 'subsample': 0.42661185347221653, 'n_estimators': 204}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:21,599] Trial 2495 finished with value: -0.5692833994697123 and parameters: {'max_depth': 17, 'gamma': 0, 'max_delta_step': 12, 'min_child_weight': 15, 'learning_rate': 0.10115291490025874, 'subsample': 0.4914036748744963, 'n_estimators': 165}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:21,758] Trial 2496 finished with value: -1.3551998611197753 and parameters: {'max_depth': 19, 'gamma': 0, 'max_delta_step': 14, 'min_child_weight': 12, 'learning_rate': 0.961914562806816, 'subsample': 0.3953440342791646, 'n_estimators': 89}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:21,904] Trial 2497 finished with value: -0.6043323822021485 and parameters: {'max_depth': 19, 'gamma': 1, 'max_delta_step': 13, 'min_child_weight': 11, 'learning_rate': 0.07451167957979693, 'subsample': 0.5108697225663797, 'n_estimators': 155}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:22,101] Trial 2498 finished with value: -0.5652227980669806 and parameters: {'max_depth': 11, 'gamma': 0, 'max_delta_step': 9, 'min_child_weight': 13, 'learning_rate': 0.10858172603567988, 'subsample': 0.4164564077671141, 'n_estimators': 147}. Best is trial 1979 with value: -0.528950914887821.
# [I 2025-08-12 00:55:22,233] Trial 2499 finished with value: -0.631365234262803 and parameters: {'max_depth': 2, 'gamma': 0, 'max_delta_step': 12, 'min_child_weight': 14, 'learning_rate': 0.04933054004245353, 'subsample': 0.5445745811517118, 'n_estimators': 195}. Best is trial 1979 with value: -0.528950914887821.
# {'max_depth': 11,
#  'gamma': 0,
#  'max_delta_step': 14,
#  'min_child_weight': 14,
#  'learning_rate': 0.10433524150608854,
#  'subsample': 0.38831917232016605,
#  'n_estimators': 101}

# %% [markdown]
# {'max_depth': 11,
#  'gamma': 0,
#  'max_delta_step': 14,
#  'min_child_weight': 14,
#  'learning_rate': 0.10433524150608854,
#  'subsample': 0.38831917232016605,
#  'n_estimators': 101}

# %%
# We can now assess the model performance on the training set using cross validation
from sklearn.metrics import mean_squared_error
import sklearn
from sklearn import metrics

print(sklearn.metrics.get_scorer_names())

CrossValAssessor(
    scoring="neg_mean_absolute_error",
    split=BootstrapSplit(split=ClusterSplit(dataset_sars), n_bootstraps=100)
)(model_sars, dataset_sars)

# and on the test set
TestSetAssessor("neg_mean_absolute_error")(model_sars, dataset_sars)
# Out:
# ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'max_error', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_negative_likelihood_ratio', 'neg_root_mean_squared_error', 'neg_root_mean_squared_log_error', 'normalized_mutual_info_score', 'positive_likelihood_ratio', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc', 'roc_auc_ovo', 'roc_auc_ovo_weighted', 'roc_auc_ovr', 'roc_auc_ovr_weighted', 'top_k_accuracy', 'v_measure_score']
# array([-0.52895091])

# %%
# Finally, we need to fit the model on the complete dataset if we want to use it further
model_sars.fitDataset(dataset_sars)

# and save the model
_ = model_sars.save()

# %%
from qsprpred.plotting.regression import CorrelationPlot

# Instantiate with a list of models
plotter = CorrelationPlot(models=[model_sars])

# Create and optionally save/show the plot
g, summary_df = plotter.make(save=True, show=True, out_path="sars_cor_plot.png")

# summary_df contains metrics like R2, RMSE per model, fold, property
print(summary_df)
# Out:
# XGMorgan_clustsplit
# /home/valerij/miniconda3/envs/pol/lib/python3.12/site-packages/qsprpred/plotting/regression.py:99: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                    Model              Fold                 Property        R2  \
# 0    XGMorgan_clustsplit               0.0  pIC50 (SARS-CoV-2 Mpro)  0.414142
# 1    XGMorgan_clustsplit               1.0  pIC50 (SARS-CoV-2 Mpro) -0.093899
# 2    XGMorgan_clustsplit               2.0  pIC50 (SARS-CoV-2 Mpro)  0.047678
# 3    XGMorgan_clustsplit               3.0  pIC50 (SARS-CoV-2 Mpro) -0.151483
# 4    XGMorgan_clustsplit               4.0  pIC50 (SARS-CoV-2 Mpro)  0.194775
# ..                   ...               ...                      ...       ...
# 96   XGMorgan_clustsplit              96.0  pIC50 (SARS-CoV-2 Mpro)  0.013815
# 97   XGMorgan_clustsplit              97.0  pIC50 (SARS-CoV-2 Mpro) -0.071423
# 98   XGMorgan_clustsplit              98.0  pIC50 (SARS-CoV-2 Mpro) -0.016195
# 99   XGMorgan_clustsplit              99.0  pIC50 (SARS-CoV-2 Mpro)  0.362045
# 100  XGMorgan_clustsplit  Independent Test  pIC50 (SARS-CoV-2 Mpro)  0.380952
#
#          RMSE               Set
# 0    0.760158  Cross Validation
# 1    1.021469  Cross Validation
# 2    0.947269  Cross Validation
# 3    1.080799  Cross Validation
# 4    0.938654  Cross Validation
# ..        ...               ...
# 96   0.984876  Cross Validation
# 97   1.007769  Cross Validation
# 98   0.998322  Cross Validation
# 99   0.832190  Cross Validation
# 100  0.846135  Independent Test
#
# [101 rows x 6 columns]

# %%
with open("sars_test.smi", "w") as f:
    for smi in test_sars_df["SMILES"]:
        f.write(f"{smi}\n")

# %%
from rdkit import Chem
from rdkit.Chem import MolStandardize

def read_smi_file(file_path):
    smiles_list = []
    try:
        with open(file_path, 'r') as file:
            for line in file:
                # Skip comment lines and empty lines
                if line.strip() and not line.startswith('#'):
                    # SMILES strings are typically separated by whitespace or tab
                    smiles = line.split()[0]
                    smiles_list.append(smiles)
    except FileNotFoundError:
        print("File not found.")
    return smiles_list

# Example usage to read the standardized SMILES file and create a list
file_path = 'sars_test.smi'
smiles_list = read_smi_file(file_path)
print("SMILES in the file:")
print(len(smiles_list))
# Out:
# SMILES in the file:
# 263

# %%
well = model_sars.predictMols(smiles_list)

# %%
print(well)
# Out:
# [[5.0967746]
#  [6.332546 ]
#  [5.1827655]
#  [6.2881947]
#  [6.4420285]
#  [6.804196 ]
#  [6.870919 ]
#  [6.0607257]
#  [6.709977 ]
#  [5.484639 ]
#  [6.9449935]
#  [6.784581 ]
#  [6.833449 ]
#  [6.8228703]
#  [6.7110386]
#  [6.5644794]
#  [6.4439363]
#  [5.4556994]
#  [6.6856503]
#  [6.5472827]
#  [6.630509 ]
#  [6.835323 ]
#  [7.57732  ]
#  [5.9577074]
#  [7.2528777]
#  [6.4181304]
#  [7.362709 ]
#  [6.4855943]
#  [5.6487904]
#  [6.727697 ]
#  [6.9122133]
#  [6.3320827]
#  [6.4801507]
#  [7.058747 ]
#  [6.613727 ]
#  [6.894493 ]
#  [6.791707 ]
#  [6.5955195]
#  [6.417431 ]
#  [6.562739 ]
#  [6.9542384]
#  [6.5409126]
#  [6.5409126]
#  [6.5328236]
#  [6.5328236]
#  [6.137743 ]
#  [6.137743 ]
#  [6.3484774]
#  [6.3484774]
#  [7.003797 ]
#  [6.605341 ]
#  [6.5530996]
#  [6.5634317]
#  [6.7269197]
#  [6.602696 ]
#  [6.830451 ]
#  [6.782026 ]
#  [6.3886285]
#  [6.7272105]
#  [6.979549 ]
#  [6.76617  ]
#  [6.716357 ]
#  [6.8964596]
#  [6.8669353]
#  [6.780404 ]
#  [7.45016  ]
#  [7.4621773]
#  [6.7735057]
#  [6.702593 ]
#  [6.6952057]
#  [7.4354343]
#  [7.3757124]
#  [6.8541694]
#  [6.5423684]
#  [6.645544 ]
#  [6.3885255]
#  [6.654854 ]
#  [6.9346614]
#  [6.914995 ]
#  [6.855387 ]
#  [6.6692743]
#  [7.3771944]
#  [6.442563 ]
#  [7.268179 ]
#  [7.151144 ]
#  [6.57663  ]
#  [7.228785 ]
#  [6.794636 ]
#  [6.78157  ]
#  [7.5672092]
#  [7.296712 ]
#  [7.5672092]
#  [7.4092937]
#  [6.571242 ]
#  [7.395629 ]
#  [7.395629 ]
#  [7.6402493]
#  [7.470637 ]
#  [7.395935 ]
#  [7.432053 ]
#  [7.3830743]
#  [7.4092937]
#  [7.470637 ]
#  [7.0788546]
#  [7.0876126]
#  [6.6397557]
#  [7.238241 ]
#  [7.1838236]
#  [6.5121703]
#  [6.561688 ]
#  [7.4740067]
#  [6.498607 ]
#  [7.4127803]
#  [6.155344 ]
#  [7.470637 ]
#  [6.2660003]
#  [6.3605924]
#  [6.343399 ]
#  [5.894826 ]
#  [5.894826 ]
#  [7.4322424]
#  [6.408947 ]
#  [7.3064547]
#  [6.369814 ]
#  [5.894826 ]
#  [6.2639947]
#  [6.3793263]
#  [4.64663  ]
#  [7.523594 ]
#  [6.2151375]
#  [4.6807313]
#  [5.1494617]
#  [4.381398 ]
#  [5.602584 ]
#  [5.766424 ]
#  [5.481671 ]
#  [6.464205 ]
#  [6.1708856]
#  [5.0807714]
#  [4.6783733]
#  [4.692322 ]
#  [4.5866895]
#  [6.052444 ]
#  [6.4023957]
#  [6.4023957]
#  [4.9554005]
#  [5.2623887]
#  [6.6792836]
#  [4.664974 ]
#  [6.686138 ]
#  [6.686138 ]
#  [4.454112 ]
#  [4.778386 ]
#  [5.6801677]
#  [5.481671 ]
#  [4.670317 ]
#  [6.086784 ]
#  [5.7870665]
#  [5.781744 ]
#  [5.0139384]
#  [7.2815413]
#  [5.714159 ]
#  [5.0923214]
#  [7.126137 ]
#  [5.707987 ]
#  [7.334899 ]
#  [5.5215826]
#  [5.3544736]
#  [7.436407 ]
#  [5.639476 ]
#  [7.483723 ]
#  [7.5059595]
#  [4.758285 ]
#  [5.644471 ]
#  [5.6197143]
#  [6.0664496]
#  [4.941683 ]
#  [5.6970997]
#  [5.4546576]
#  [5.733814 ]
#  [6.2814445]
#  [6.475119 ]
#  [5.3521223]
#  [6.345524 ]
#  [6.104408 ]
#  [6.104408 ]
#  [6.320749 ]
#  [5.5350018]
#  [4.823396 ]
#  [4.3230443]
#  [4.6196737]
#  [5.086153 ]
#  [5.190423 ]
#  [5.190423 ]
#  [4.490631 ]
#  [4.490631 ]
#  [5.946851 ]
#  [4.6091814]
#  [4.6091814]
#  [5.296218 ]
#  [5.296218 ]
#  [4.443308 ]
#  [6.4607882]
#  [6.4607882]
#  [4.658834 ]
#  [4.0536137]
#  [4.0536137]
#  [4.911467 ]
#  [4.3491473]
#  [4.8707385]
#  [4.6511025]
#  [4.698141 ]
#  [4.9059944]
#  [4.650327 ]
#  [4.7117558]
#  [5.09973  ]
#  [5.09973  ]
#  [4.9479833]
#  [4.607192 ]
#  [5.213886 ]
#  [4.283854 ]
#  [4.009235 ]
#  [4.530469 ]
#  [5.4821424]
#  [4.686193 ]
#  [4.686193 ]
#  [5.0018187]
#  [4.5822845]
#  [5.35984  ]
#  [5.225643 ]
#  [5.946851 ]
#  [5.697396 ]
#  [4.609623 ]
#  [4.865146 ]
#  [4.589311 ]
5350018, 4.823396, 4.3230443, 4.6196737, 5.086153, 5.190423, 5.190423, 4.490631, 4.490631, 5.946851, 4.6091814, 4.6091814, 5.296218, 5.296218, 4.443308, 6.4607882, 6.4607882, 4.658834, 4.0536137, 4.0536137, 4.911467, 4.3491473, 4.8707385, 4.6511025, 4.698141, 4.9059944, 4.650327, 4.7117558, 5.09973, 5.09973, 4.9479833, 4.607192, 5.213886, 4.283854, 4.009235, 4.530469, 5.4821424, 4.686193, 4.686193, 5.0018187, 4.5822845, 5.35984, 5.225643, 5.946851, 5.697396, 4.609623, 4.865146, 4.589311, 4.420019, 5.635719, 4.3989215, 5.334259, 5.334259, 4.2936625, 4.3916187, 5.7076974, 4.861008, 4.7484283, 4.5399337, 4.0468454, 5.3734713, 4.7386804, 4.0373063, 4.0373063, 4.0854874, 4.2943234, 5.1765957, 4.8307805, 4.8307805, 4.1888447, 4.093171, 4.093171, 4.093171, 4.8307805, 5.9830213, 5.9830213]

# %%
import csv
# Write to CSV file
with open("sars_prediction_final.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["SMILES", "SARS"])
    for smiles, value in zip(smiles_list, values):
        writer.writerow([smiles, value])

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
pd.read_csv("sars_prediction_final.csv")
# Out:
#                                                 SMILES      SARS
# 0    C=CC(=O)Nc1cccc(N(Cc2cccc(Cl)c2)C(=O)Cc2cncc3c...  5.096775
# 1    CNC(=O)CN1C[C@]2(CCN(c3cncc4ccc(OC[C@H](O)CN(C...  6.332546
# 2    CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...  5.182766
# 3    CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...  6.288195
# 4    CNC(=O)CN1C[C@]2(C(=O)N(c3cncc4ccccc34)C[C@H]2...  6.442029
# ..                                                 ...       ...
# 258        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1  4.093171
# 259        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1  4.093171
# 260        O=C(Cc1cncc2ccccc12)N1CCC[C@H]2CCCC[C@@H]21  4.830781
# 261  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12  5.983021
# 262  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12  5.983021
#
# [263 rows x 2 columns]

# %%
test_sars_df["predicted SARS"] = values

# %%
test_sars_df
# Out:
#                                                                          SMILES  \
# QSPRID
# MultiTaskTutorialDataset_000  C=CC(=O)Nc1cccc(N(Cc2cccc(Cl)c2)C(=O)Cc2cncc3c...
# MultiTaskTutorialDataset_001  CNC(=O)CN1C[C@]2(CCN(c3cncc4ccc(OC[C@H](O)CN(C...
# MultiTaskTutorialDataset_002  CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...
# MultiTaskTutorialDataset_003  CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H...
# MultiTaskTutorialDataset_004  CNC(=O)CN1C[C@]2(C(=O)N(c3cncc4ccccc34)C[C@H]2...
# ...                                                                         ...
# MultiTaskTutorialDataset_258        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1
# MultiTaskTutorialDataset_259        O=C(Cc1cncc2ccccc12)N1CCCC[C@H]1[C@H]1CCCO1
# MultiTaskTutorialDataset_260        O=C(Cc1cncc2ccccc12)N1CCC[C@H]2CCCC[C@@H]21
# MultiTaskTutorialDataset_261  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12
# MultiTaskTutorialDataset_262  COc1ccccc1[C@H]1C[C@H](C)CCN1C(=O)Cc1cncc2ccccc12
#
#                              Molecule Name   Set  pIC50 (MERS-CoV Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000  ASAP-0000175  Test                   5.52
# MultiTaskTutorialDataset_001  ASAP-0000528  Test                   5.80
# MultiTaskTutorialDataset_002  ASAP-0000541  Test                   5.81
# MultiTaskTutorialDataset_003  ASAP-0000733  Test                   6.69
# MultiTaskTutorialDataset_004  ASAP-0000738  Test                   5.98
# ...                                    ...   ...                    ...
# MultiTaskTutorialDataset_258  ASAP-0032560  Test                   4.33
# MultiTaskTutorialDataset_259  ASAP-0032561  Test                   4.54
# MultiTaskTutorialDataset_260  ASAP-0032572  Test                   4.84
# MultiTaskTutorialDataset_261  ASAP-0032604  Test                   5.53
# MultiTaskTutorialDataset_262  ASAP-0032605  Test                   5.47
#
#                               pIC50 (SARS-CoV-2 Mpro)  \
# QSPRID
# MultiTaskTutorialDataset_000                     5.57
# MultiTaskTutorialDataset_001                     7.44
# MultiTaskTutorialDataset_002                     6.48
# MultiTaskTutorialDataset_003                     7.87
# MultiTaskTutorialDataset_004                     7.60
# ...                                               ...
# MultiTaskTutorialDataset_258                     4.02
# MultiTaskTutorialDataset_259                     4.20
# MultiTaskTutorialDataset_260                     5.18
# MultiTaskTutorialDataset_261                     5.59
# MultiTaskTutorialDataset_262                     5.77
#
#                                                     QSPRID  \
# QSPRID
# MultiTaskTutorialDataset_000  MultiTaskTutorialDataset_000
# MultiTaskTutorialDataset_001  MultiTaskTutorialDataset_001
# MultiTaskTutorialDataset_002  MultiTaskTutorialDataset_002
# MultiTaskTutorialDataset_003  MultiTaskTutorialDataset_003
# MultiTaskTutorialDataset_004  MultiTaskTutorialDataset_004
# ...                                                    ...
# MultiTaskTutorialDataset_258  MultiTaskTutorialDataset_258
# MultiTaskTutorialDataset_259  MultiTaskTutorialDataset_259
# MultiTaskTutorialDataset_260  MultiTaskTutorialDataset_260
# MultiTaskTutorialDataset_261  MultiTaskTutorialDataset_261
# MultiTaskTutorialDataset_262  MultiTaskTutorialDataset_262
#
#                               pIC50 (SARS-CoV-2 Mpro)_original  Split_IsTrain  \
# QSPRID
# MultiTaskTutorialDataset_000                              5.57           True
# MultiTaskTutorialDataset_001                              7.44          False
# MultiTaskTutorialDataset_002                              6.48           True
# MultiTaskTutorialDataset_003                              7.87           True
# MultiTaskTutorialDataset_004                              7.60           True
# ...                                                        ...            ...
# MultiTaskTutorialDataset_258                              4.02           True
# MultiTaskTutorialDataset_259                              4.20           True
# MultiTaskTutorialDataset_260                              5.18           True
# MultiTaskTutorialDataset_261                              5.59          False
# MultiTaskTutorialDataset_262                              5.77          False
#
#                               predicted SARS
# QSPRID
# MultiTaskTutorialDataset_000        5.096775
# MultiTaskTutorialDataset_001        6.332546
# MultiTaskTutorialDataset_002        5.182765
# MultiTaskTutorialDataset_003        6.288195
# MultiTaskTutorialDataset_004        6.442029
# ...                                      ...
# MultiTaskTutorialDataset_258        4.093171
# MultiTaskTutorialDataset_259        4.093171
# MultiTaskTutorialDataset_260        4.830781
# MultiTaskTutorialDataset_261        5.983021
# MultiTaskTutorialDataset_262        5.983021
#
# [263 rows x 9 columns]

# %%
test_sars_df.to_csv("sars_predicted_true.csv")

# %% [markdown]
# The End.
